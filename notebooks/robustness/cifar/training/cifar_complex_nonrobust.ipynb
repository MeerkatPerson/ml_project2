# %%
# Requirements
# !pip install tensorflow_datasets flax jax optax tqdm netket imgaug==0.2.6

# %%
import jax
import jax.numpy as jnp
import numpy as np
from matplotlib import pyplot as plt
import tensorflow_datasets as tfds
import jax
import jax.numpy as jnp
import jax
import flax
import netket as nk
import jax.numpy as jnp
from jax.experimental import stax
import optax
from flax.training import train_state  # Useful dataclass to keep train state
from functools import partial
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# ### Utility Functions

# %%
def show_img(img, ax=None, title=None):
  """Shows a single image.
  
  Must be stored as a 3d-tensor where the last dimension is 1 channel (greyscale)
  """
  if ax is None:
    ax = plt.gca()
  ax.imshow(img)
  ax.set_xticks([])
  ax.set_yticks([])
  if title:
    ax.set_title(title)

def show_img_grid(imgs, titles):
  """Shows a grid of images."""
  n = int(np.ceil(len(imgs)**.5))
  _, axs = plt.subplots(n, n, figsize=(3 * n, 3 * n))
  for i, (img, title) in enumerate(zip(imgs, titles)):
    show_img(img, axs[i // n][i % n], title)

# %% [markdown]
# ## Setting up the dataset

# %%
#import
ds_builder = tfds.builder('cifar10')
ds_builder.download_and_prepare()
train_ds = tfds.as_numpy(ds_builder.as_dataset(split='train', batch_size=-1))
test_ds = tfds.as_numpy(ds_builder.as_dataset(split='test', batch_size=-1))

#delete the id 
del train_ds['id']
del test_ds['id']


# Normalize
train_ds['image'] = jnp.float32(train_ds['image']) / 255.
test_ds['image'] = jnp.float32(test_ds['image']) / 255.
print("dataset keys:", train_ds.keys())
print(f"The training dataset has shape: {train_ds['image'].shape} and dtype {train_ds['image'].dtype}")
print(f"The test     dataset has shape: {test_ds['image'].shape} and dtype {train_ds['image'].dtype}")
print("")
print(f"The training labels have shape: {train_ds['label'].shape} and dtype {train_ds['label'].dtype}")
print(f"The test     labels have shape: {test_ds['label'].shape} and dtype {test_ds['label'].dtype}")
print("The mean     of the data stored in the images are: ", np.mean(train_ds['image']))
print("The variance of the data stored in the images are: ", np.var(train_ds['image']))
# Out:
# Downloading and preparing dataset cifar10/3.0.2 (download: 162.17 MiB, generated: 132.40 MiB, total: 294.58 MiB) to /root/tensorflow_datasets/cifar10/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incompleteHLRBHX/cifar10-train.tfrecord
#   0%|          | 0/50000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incompleteHLRBHX/cifar10-test.tfrecord
#   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py:598: get_single_element (from tensorflow.python.data.experimental.ops.get_single_element) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.get_single_element()`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py:598: get_single_element (from tensorflow.python.data.experimental.ops.get_single_element) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.get_single_element()`.
# dataset keys: dict_keys(['image', 'label'])
# The training dataset has shape: (50000, 32, 32, 3) and dtype float32
# The test     dataset has shape: (10000, 32, 32, 3) and dtype float32
#
# The training labels have shape: (50000,) and dtype int64
# The test     labels have shape: (10000,) and dtype int64
# The mean     of the data stored in the images are:  0.47336298
# The variance of the data stored in the images are:  0.063286915

# %% [markdown]
# ## Non-linearities

# %%
def modRelu(z, bias): # relu(|z|+b) * (z / |z|)
    norm = jnp.abs(z)
    scale = nk.nn.relu(norm + bias) / (norm + 1e-6)
    scaled = jax.lax.complex(jnp.real(z)*scale, jnp.imag(z)*scale)
    return scaled

# %%
def complex_relu(z):
    return jnp.where(z.real > 0, z, 0)
complex_relu = jax.jit(complex_relu)
modRelu=jax.jit(modRelu)

# %%
def zrelu(z, epsilon=1e-7):
    """
    zReLU presented in "On Complex Valued Convolutional Neural Networks"
        from Nitzan Guberman (2016).
    This methods let's the output as the input if both real and imaginary parts are positive.
    https://stackoverflow.com/questions/49412717/advanced-custom-activation-function-in-keras-tensorflow
    """
    imag_relu = jax.nn.relu(z.imag)
    real_relu = jax.nn.relu(z.real)
    ret_real = imag_relu*real_relu / (imag_relu + epsilon)
    ret_imag = imag_relu*real_relu / (real_relu + epsilon)
    ret_val = ret_real + 1j * ret_imag
    return ret_val

# %%
def complex_cardioid(z):
    """
    Complex cardioid presented in "Better than Real: Complex-valued Neural Nets for MRI Fingerprinting"
        from V. Patrick (2017).
        
    This function maintains the phase information while attenuating the magnitude based on the phase itself. 
    For real-valued inputs, it reduces to the ReLU.
    """
    return ((1 + jnp.cos(jnp.angle(z))) + 0j) * z / 2.

# %% [markdown]
# ## Define Model

# %%
# You can add a fft layer here. You can have up to 2. It is better to put them at the beginning or at the end
class Model(nk.nn.Module):
  n_classes : int = 10
  @nk.nn.compact
  def __call__(self, x, train):
    #make rng for dropoutlayer
    dropout_rng = self.make_rng('dropout')

    
    #first TWO convolutions 3x3 --> 32. Avgpol 2x2 stride 2x2. Dropout 0.2
    x = nk.nn.Conv(features=32, kernel_size=(3, 3), dtype = complex)(x)
    x = nk.nn.relu(x)
    x = nk.nn.Conv(features=32, kernel_size=(3, 3), dtype = complex)(x)
    x = nk.nn.relu(x)
    x = flax.linen.avg_pool(x, window_shape=(2, 2), strides=(2, 2))
    x = flax.linen.Dropout(0.2, deterministic=not train)(x)

    #second TWO convolutions 64x64 --> 32. Avgpol 2x2 stride 2x2. Dropout 0.2
    x = nk.nn.Conv(features=64, kernel_size=(3, 3), dtype = complex)(x)
    x = nk.nn.relu(x)
    x = nk.nn.Conv(features=64, kernel_size=(3, 3), dtype = complex)(x)
    x = nk.nn.relu(x)
    x = flax.linen.avg_pool(x, window_shape=(2, 2), strides=(2, 2))
    x = flax.linen.Dropout(0.2, deterministic=not train)(x)

    #third TWO convolutions 128x128 --> 32. Avgpol 2x2 stride 2x2. Dropout 0.2
    x = nk.nn.Conv(features=128, kernel_size=(3, 3), dtype = complex)(x)
    x = nk.nn.relu(x)
    x = nk.nn.Conv(features=128, kernel_size=(3, 3), dtype = complex)(x)
    x = nk.nn.relu(x)
    x = flax.linen.avg_pool(x, window_shape=(2, 2), strides=(2, 2))
    x = flax.linen.Dropout(0.2, deterministic=not train)(x)

    #flatten and dense
    x = x.reshape((x.shape[0], -1))
    x = nk.nn.Dense(features=128, dtype=complex)(x)
    x = complex_relu(x)

    #DROPOUT 2
    #x = flax.linen.Dropout(0.5, deterministic=not train)(x) 

    #dense2 and softmax
    x = nk.nn.Dense(features=10, dtype=complex)(x)    # There are 10 classes in MNIST
    x = jnp.abs(x)
    x = nk.nn.log_softmax(x)

    return x

# %% [markdown]
# ## Loss functions

# %%
# The loss function that we will use
def cross_entropy(*, logits, labels):
    one_hot_labels = jax.nn.one_hot(labels, num_classes=10)
    return -jnp.mean(jnp.sum(one_hot_labels * logits, axis=-1))

# %%
dropout_rng, init_dropout = jax.random.split(jax.random.PRNGKey(1))

# %%
def loss_fn(params, dropout_rng, images, labels):
    """
    Loss function minimised during training of the model.
    """
    logits = model.apply(params, images, rngs={'dropout' : dropout_rng}, train=True)
    return cross_entropy(logits=logits, labels=labels)

def compute_metrics(*, logits, labels):
    """
    Compute metrics of the model during training.
    
    Returns the loss and the accuracy.
    """
    loss = cross_entropy(logits=logits, labels=labels)
    accuracy = jnp.mean(jnp.argmax(logits, -1) == labels)
    metrics = {
      'loss': loss,
      'accuracy': accuracy,
    }
    return metrics

# %% [markdown]
# ## 4 - Create the setup and training loop

# %%
def create_train_state(example, rng, optimiser, dropout_rng):
    """Creates initial `TrainState`, holding the current parameters, state of the
    optimiser and other metadata.
    """
    # Construct the model parameters
    params = model.init({'params' : rng, 'dropout' : dropout_rng}, example, train=True)
        
    # Package all those informations in the model state
    return train_state.TrainState.create(
        apply_fn=model.apply, params=params, tx=optimiser)

# %%
@jax.jit
def eval_metrics(params, batch, dropout_rng):
    """
    This function evaluates the metrics without training the model.
    
    Used to check the performance of the network on training and test datasets.
    """
    logits = model.apply(params, batch['image'], rngs={'dropout' : dropout_rng}, train=False)
    return compute_metrics(logits=logits, labels=batch['label'])

# %%
def fgsm_update(image, data_grad, update_max_norm):
    """
    Compute the FGSM update on an image (or a batch of images)

    @param image: float32 tensor of shape (batch_size, rgb, height, width)
    @param data_grad: float32 tensor of the same shape as `image`. Gradient of the loss with respect to `image`.
    @param update_max_norm: float, the maximum permitted difference between `image` and the output of this function measured in L_inf norm.

    @returns a perturbed version of `image` with the same shape
    """
    # Collect the element-wise sign of the data gradient
    sign_data_grad = jnp.sign(data_grad)
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + update_max_norm*sign_data_grad
    # Adding clipping to maintain [0,1] range
    perturbed_image = jnp.clip(perturbed_image, 0, 1)
    # Return the perturbed image
    return perturbed_image

# %%
def loss_fn2(images, params, dropout_rng, labels):
    """
    Loss function minimised during training of the model.
    """
    logits = model.apply(params, images, rngs={'dropout' : dropout_rng}, train=True)
    return cross_entropy(logits=logits, labels=labels)

# %%
@jax.jit
def train_step(state, batch, dropout_rng):
    """
    Train for a single step.
    
    """
    #Make parameters the only 'free' parameter
    _loss_fn = partial(loss_fn, dropout_rng = dropout_rng, images=batch['image'], labels=batch['label'])
    # construct the function returning the loss value and gradient.
    val_grad_fn = jax.value_and_grad(_loss_fn)
    # compute loss and gradient
    loss, grads = val_grad_fn(state.params)
    grads = jax.tree_map(lambda x: x.conj(), grads) 
    # update the state parameters 
    state = state.apply_gradients(grads=grads)
    #compute the metrics
    metrics = eval_metrics(state.params, batch, dropout_rng)
    
    return state, metrics

# %%
def train_epoch(state, train_ds, batch_size, epoch, rng, dropout_rng, *, max_steps=None):
    """Train for a single `epoch`.
    
    And epoch is composed of several steps, where every step is taken by updating
    the network parameters with a small mini-batch.
    """
    
    # total number of training images
    train_ds_size = len(train_ds['image'])
    
    # Compute how many steps are present in this epoch.
    steps_per_epoch = train_ds_size // batch_size

    # Truncate the number of steps
    if max_steps is not None:
        steps_per_epoch = min(steps_per_epoch, max_steps)

    # generate a random permutation of the indices to shuffle the training
    perms = jax.random.permutation(rng, train_ds_size)
    perms = perms[:steps_per_epoch * batch_size]
    perms = perms.reshape((steps_per_epoch, batch_size))
    
    # execute the training step for every mini-batch
    batch_metrics = []
    for perm in perms:
        batch = {k: v[perm, ...] for k, v in train_ds.items()}
        state, metrics = train_step(state, batch, dropout_rng)
        batch_metrics.append(metrics)

    # compute mean of metrics across each batch in epoch.
    batch_metrics_np = jax.device_get(batch_metrics)
    epoch_metrics_np = {
        k: np.mean([metrics[k] for metrics in batch_metrics_np])
            for k in batch_metrics_np[0]}

    return state, epoch_metrics_np


def evaluate_model(params, test_ds, dropout_rng):
    """
    evaluate the performance of the model on the test dataset
    """
    metrics = eval_metrics(params, test_ds, dropout_rng)
    metrics = jax.device_get(metrics)
    summary = jax.tree_map(lambda x: x.item(), metrics)
    return summary['loss'], summary['accuracy']

# %% [markdown]
# # 5 - Training model

# %%
models_saved = []
for s in range(5):
  # Definition of optimiser HyperParameters
  learning_rate = 0.005
  momentum = 0.9
  optimiser = optax.sgd(learning_rate, momentum)
  num_epochs = 80
  batch_size = 250
  max_steps = 200

  #define rngs
  seed = s #123
  seed_dropout = 10-s #0
  key = {'params': jax.random.PRNGKey(seed), 'dropout': jax.random.PRNGKey(seed_dropout)}

  #init model
  model = Model(n_classes=10)
  sample_input = jnp.ones([1, 32, 32, 3])
  pars = model.init(key, sample_input, train=True)

  # Split the rng to get two keys, one to 'shuffle' the dataset at every iteration,
  # and one to initialise the network
  rng, init_rng = jax.random.split(jax.random.PRNGKey(s))

  state = create_train_state(sample_input, init_rng, optimiser, init_dropout)
  metrics = {"test_loss" : [], "test_accuracy": [], "train_loss":[], "train_accuracy":[]}
  with tqdm(range(1, num_epochs + 1)) as pbar:
      for epoch in pbar:
          # Use a separate PRNG key to permute image data during shuffling
          rng, input_rng = jax.random.split(rng)
          dropout_rng, _ = jax.random.split(dropout_rng)
          # Run an optimization step over a training batch
          state, train_metrics = train_epoch(state, train_ds, batch_size, epoch, input_rng, dropout_rng)
          
          # Evaluate on the test set after each training epoch
          test_loss, test_accuracy = evaluate_model(state.params, test_ds, dropout_rng)
          pbar.write('train epoch: %d, loss: %.4f, accuracy: %.2f' % (epoch, train_metrics['loss'], train_metrics['accuracy'] * 100))
          pbar.write(' test epoch: %d, loss: %.2f, accuracy: %.2f' % (epoch, test_loss, test_accuracy * 100))

          # save data
          metrics["train_loss"].append(train_metrics["loss"])
          metrics["train_accuracy"].append(train_metrics["accuracy"])
          metrics["test_loss"].append(test_loss)
          metrics["test_accuracy"].append(test_accuracy)

  models_saved += [state]
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]
# train epoch: 1, loss: 2.2029, accuracy: 18.61
#  test epoch: 1, loss: 2.06, accuracy: 26.12
# train epoch: 2, loss: 1.8458, accuracy: 33.52
#  test epoch: 2, loss: 1.72, accuracy: 38.56
# train epoch: 3, loss: 1.6587, accuracy: 40.22
#  test epoch: 3, loss: 1.72, accuracy: 39.65
# train epoch: 4, loss: 1.5303, accuracy: 45.32
#  test epoch: 4, loss: 1.54, accuracy: 45.16
# train epoch: 5, loss: 1.4395, accuracy: 48.12
#  test epoch: 5, loss: 1.41, accuracy: 48.89
# train epoch: 6, loss: 1.3586, accuracy: 51.38
#  test epoch: 6, loss: 1.35, accuracy: 51.43
# train epoch: 7, loss: 1.2961, accuracy: 53.73
#  test epoch: 7, loss: 1.28, accuracy: 54.52
# train epoch: 8, loss: 1.2488, accuracy: 55.64
#  test epoch: 8, loss: 1.25, accuracy: 55.31
# train epoch: 9, loss: 1.1991, accuracy: 57.37
#  test epoch: 9, loss: 1.25, accuracy: 55.40
# train epoch: 10, loss: 1.1504, accuracy: 59.55
#  test epoch: 10, loss: 1.21, accuracy: 56.68
# train epoch: 11, loss: 1.0996, accuracy: 61.29
#  test epoch: 11, loss: 1.15, accuracy: 59.13
# train epoch: 12, loss: 1.0605, accuracy: 62.45
#  test epoch: 12, loss: 1.11, accuracy: 60.58
# train epoch: 13, loss: 1.0299, accuracy: 63.77
#  test epoch: 13, loss: 1.09, accuracy: 60.92
# train epoch: 14, loss: 0.9781, accuracy: 65.65
#  test epoch: 14, loss: 1.09, accuracy: 61.25
# train epoch: 15, loss: 0.9455, accuracy: 66.77
#  test epoch: 15, loss: 1.06, accuracy: 62.53
# train epoch: 16, loss: 0.9041, accuracy: 68.20
#  test epoch: 16, loss: 1.07, accuracy: 61.96
# train epoch: 17, loss: 0.8765, accuracy: 69.36
#  test epoch: 17, loss: 1.03, accuracy: 63.73
# train epoch: 18, loss: 0.8440, accuracy: 70.70
#  test epoch: 18, loss: 0.99, accuracy: 64.64
# train epoch: 19, loss: 0.8012, accuracy: 72.18
#  test epoch: 19, loss: 0.97, accuracy: 65.44
# train epoch: 20, loss: 0.7775, accuracy: 72.72
#  test epoch: 20, loss: 0.97, accuracy: 65.98
# train epoch: 21, loss: 0.7380, accuracy: 74.23
#  test epoch: 21, loss: 0.95, accuracy: 66.42
# train epoch: 22, loss: 0.6997, accuracy: 75.65
#  test epoch: 22, loss: 0.97, accuracy: 66.18
# train epoch: 23, loss: 0.6772, accuracy: 76.54
#  test epoch: 23, loss: 0.97, accuracy: 66.99
# train epoch: 24, loss: 0.6397, accuracy: 77.96
#  test epoch: 24, loss: 0.94, accuracy: 67.52
# train epoch: 25, loss: 0.6158, accuracy: 78.64
#  test epoch: 25, loss: 0.93, accuracy: 68.00
# train epoch: 26, loss: 0.5882, accuracy: 79.62
#  test epoch: 26, loss: 0.90, accuracy: 68.95
# train epoch: 27, loss: 0.5566, accuracy: 80.69
#  test epoch: 27, loss: 0.94, accuracy: 68.53
# train epoch: 28, loss: 0.5339, accuracy: 81.63
#  test epoch: 28, loss: 0.92, accuracy: 68.67
# train epoch: 29, loss: 0.5067, accuracy: 82.50
#  test epoch: 29, loss: 0.91, accuracy: 69.49
# train epoch: 30, loss: 0.4793, accuracy: 83.64
#  test epoch: 30, loss: 0.90, accuracy: 69.68
# train epoch: 31, loss: 0.4556, accuracy: 84.44
#  test epoch: 31, loss: 0.94, accuracy: 69.46
# train epoch: 32, loss: 0.4329, accuracy: 85.31
#  test epoch: 32, loss: 0.91, accuracy: 69.90
# train epoch: 33, loss: 0.4093, accuracy: 86.12
#  test epoch: 33, loss: 0.89, accuracy: 70.06
# train epoch: 34, loss: 0.3782, accuracy: 87.20
#  test epoch: 34, loss: 0.92, accuracy: 70.36
# train epoch: 35, loss: 0.3528, accuracy: 88.14
#  test epoch: 35, loss: 0.91, accuracy: 70.40
# train epoch: 36, loss: 0.3333, accuracy: 88.91
#  test epoch: 36, loss: 0.92, accuracy: 70.85
# train epoch: 37, loss: 0.3177, accuracy: 89.35
#  test epoch: 37, loss: 0.91, accuracy: 70.69
# train epoch: 38, loss: 0.2923, accuracy: 90.33
#  test epoch: 38, loss: 0.91, accuracy: 70.86
# train epoch: 39, loss: 0.2748, accuracy: 90.99
#  test epoch: 39, loss: 0.93, accuracy: 70.61
# train epoch: 40, loss: 0.2635, accuracy: 91.34
#  test epoch: 40, loss: 0.98, accuracy: 70.98
# train epoch: 41, loss: 0.2426, accuracy: 92.00
#  test epoch: 41, loss: 0.95, accuracy: 71.32
# train epoch: 42, loss: 0.2300, accuracy: 92.59
#  test epoch: 42, loss: 0.98, accuracy: 71.58
# train epoch: 43, loss: 0.2097, accuracy: 93.27
#  test epoch: 43, loss: 0.92, accuracy: 71.45
# train epoch: 44, loss: 0.2002, accuracy: 93.53
#  test epoch: 44, loss: 0.98, accuracy: 71.44
# train epoch: 45, loss: 0.1878, accuracy: 94.15
#  test epoch: 45, loss: 0.99, accuracy: 71.51
# train epoch: 46, loss: 0.1777, accuracy: 94.38
#  test epoch: 46, loss: 0.95, accuracy: 72.62
# train epoch: 47, loss: 0.1663, accuracy: 94.83
#  test epoch: 47, loss: 0.94, accuracy: 72.46
# train epoch: 48, loss: 0.1521, accuracy: 95.39
#  test epoch: 48, loss: 0.98, accuracy: 72.51
# train epoch: 49, loss: 0.1445, accuracy: 95.70
#  test epoch: 49, loss: 0.99, accuracy: 71.86
# train epoch: 50, loss: 0.1316, accuracy: 96.05
#  test epoch: 50, loss: 1.05, accuracy: 71.36
# train epoch: 51, loss: 0.1300, accuracy: 96.14
#  test epoch: 51, loss: 0.98, accuracy: 72.33
# train epoch: 52, loss: 0.1159, accuracy: 96.65
#  test epoch: 52, loss: 1.02, accuracy: 71.80
# train epoch: 53, loss: 0.1041, accuracy: 97.00
#  test epoch: 53, loss: 0.99, accuracy: 72.44
# train epoch: 54, loss: 0.0999, accuracy: 97.20
#  test epoch: 54, loss: 1.04, accuracy: 72.31
# train epoch: 55, loss: 0.0886, accuracy: 97.54
#  test epoch: 55, loss: 1.04, accuracy: 72.34
# train epoch: 56, loss: 0.0859, accuracy: 97.63
#  test epoch: 56, loss: 1.05, accuracy: 72.68
# train epoch: 57, loss: 0.0861, accuracy: 97.50
#  test epoch: 57, loss: 1.03, accuracy: 71.88
# train epoch: 58, loss: 0.0819, accuracy: 97.73
#  test epoch: 58, loss: 1.03, accuracy: 71.86
# train epoch: 59, loss: 0.0764, accuracy: 97.97
#  test epoch: 59, loss: 1.08, accuracy: 72.46
# train epoch: 60, loss: 0.0725, accuracy: 98.04
#  test epoch: 60, loss: 1.07, accuracy: 72.85
# train epoch: 61, loss: 0.0681, accuracy: 98.19
#  test epoch: 61, loss: 1.06, accuracy: 72.63
# train epoch: 62, loss: 0.0658, accuracy: 98.33
#  test epoch: 62, loss: 1.04, accuracy: 72.66
# train epoch: 63, loss: 0.0561, accuracy: 98.61
#  test epoch: 63, loss: 1.11, accuracy: 72.93
# train epoch: 64, loss: 0.0548, accuracy: 98.61
#  test epoch: 64, loss: 1.11, accuracy: 72.36
# train epoch: 65, loss: 0.0531, accuracy: 98.61
#  test epoch: 65, loss: 1.10, accuracy: 73.15
# train epoch: 66, loss: 0.0454, accuracy: 98.87
#  test epoch: 66, loss: 1.12, accuracy: 73.24
# train epoch: 67, loss: 0.0500, accuracy: 98.69
#  test epoch: 67, loss: 1.13, accuracy: 72.84
# train epoch: 68, loss: 0.0464, accuracy: 98.88
#  test epoch: 68, loss: 1.14, accuracy: 73.36
# train epoch: 69, loss: 0.0430, accuracy: 98.94
#  test epoch: 69, loss: 1.12, accuracy: 73.75
# train epoch: 70, loss: 0.0411, accuracy: 98.97
#  test epoch: 70, loss: 1.14, accuracy: 73.24
# train epoch: 71, loss: 0.0360, accuracy: 99.21
#  test epoch: 71, loss: 1.17, accuracy: 73.00
# train epoch: 72, loss: 0.0344, accuracy: 99.22
#  test epoch: 72, loss: 1.17, accuracy: 72.95
# train epoch: 73, loss: 0.0331, accuracy: 99.23
#  test epoch: 73, loss: 1.18, accuracy: 73.44
# train epoch: 74, loss: 0.0339, accuracy: 99.16
#  test epoch: 74, loss: 1.20, accuracy: 73.24
# train epoch: 75, loss: 0.0399, accuracy: 99.00
#  test epoch: 75, loss: 1.14, accuracy: 73.16
# train epoch: 76, loss: 0.0406, accuracy: 99.02
#  test epoch: 76, loss: 1.11, accuracy: 73.81
# train epoch: 77, loss: 0.0337, accuracy: 99.22
#  test epoch: 77, loss: 1.15, accuracy: 73.62
# train epoch: 78, loss: 0.0292, accuracy: 99.32
#  test epoch: 78, loss: 1.12, accuracy: 74.17
# train epoch: 79, loss: 0.0276, accuracy: 99.39
#  test epoch: 79, loss: 1.15, accuracy: 73.60
# train epoch: 80, loss: 0.0306, accuracy: 99.28
#  test epoch: 80, loss: 1.17, accuracy: 74.33
#   0%|          | 0/80 [00:00<?, ?it/s]
# train epoch: 1, loss: 2.2090, accuracy: 16.12
#  test epoch: 1, loss: 1.99, accuracy: 26.89
# train epoch: 2, loss: 1.8277, accuracy: 33.86
#  test epoch: 2, loss: 1.67, accuracy: 41.09
# train epoch: 3, loss: 1.6300, accuracy: 41.73
#  test epoch: 3, loss: 1.56, accuracy: 44.37
# train epoch: 4, loss: 1.5191, accuracy: 45.74
#  test epoch: 4, loss: 1.46, accuracy: 47.36
# train epoch: 5, loss: 1.4313, accuracy: 49.03
#  test epoch: 5, loss: 1.40, accuracy: 49.44
# train epoch: 6, loss: 1.3638, accuracy: 51.37
#  test epoch: 6, loss: 1.35, accuracy: 51.63
# train epoch: 7, loss: 1.2956, accuracy: 53.96
#  test epoch: 7, loss: 1.29, accuracy: 53.03
# train epoch: 8, loss: 1.2447, accuracy: 55.92
#  test epoch: 8, loss: 1.29, accuracy: 54.46
# train epoch: 9, loss: 1.1910, accuracy: 57.66
#  test epoch: 9, loss: 1.21, accuracy: 56.57
# train epoch: 10, loss: 1.1342, accuracy: 59.75
#  test epoch: 10, loss: 1.20, accuracy: 57.06
# train epoch: 11, loss: 1.0903, accuracy: 61.66
#  test epoch: 11, loss: 1.17, accuracy: 58.09
# train epoch: 12, loss: 1.0419, accuracy: 63.37
#  test epoch: 12, loss: 1.10, accuracy: 60.81
# train epoch: 13, loss: 0.9955, accuracy: 64.99
#  test epoch: 13, loss: 1.10, accuracy: 60.92
# train epoch: 14, loss: 0.9526, accuracy: 66.54
#  test epoch: 14, loss: 1.07, accuracy: 62.07
# train epoch: 15, loss: 0.9069, accuracy: 67.93
#  test epoch: 15, loss: 1.07, accuracy: 62.13
# train epoch: 16, loss: 0.8747, accuracy: 69.25
#  test epoch: 16, loss: 1.02, accuracy: 63.89
# train epoch: 17, loss: 0.8449, accuracy: 70.43
#  test epoch: 17, loss: 1.01, accuracy: 64.46
# train epoch: 18, loss: 0.7994, accuracy: 72.22
#  test epoch: 18, loss: 1.03, accuracy: 63.89
# train epoch: 19, loss: 0.7689, accuracy: 73.09
#  test epoch: 19, loss: 0.99, accuracy: 65.45
# train epoch: 20, loss: 0.7393, accuracy: 74.34
#  test epoch: 20, loss: 0.95, accuracy: 66.41
# train epoch: 21, loss: 0.7147, accuracy: 75.26
#  test epoch: 21, loss: 0.96, accuracy: 66.69
# train epoch: 22, loss: 0.6704, accuracy: 76.66
#  test epoch: 22, loss: 0.94, accuracy: 67.32
# train epoch: 23, loss: 0.6458, accuracy: 77.70
#  test epoch: 23, loss: 0.94, accuracy: 67.72
# train epoch: 24, loss: 0.6243, accuracy: 78.33
#  test epoch: 24, loss: 0.91, accuracy: 68.67
# train epoch: 25, loss: 0.5815, accuracy: 79.76
#  test epoch: 25, loss: 0.91, accuracy: 68.51
# train epoch: 26, loss: 0.5572, accuracy: 80.83
#  test epoch: 26, loss: 0.88, accuracy: 69.94
# train epoch: 27, loss: 0.5243, accuracy: 81.85
#  test epoch: 27, loss: 0.88, accuracy: 69.81
# train epoch: 28, loss: 0.5040, accuracy: 82.62
#  test epoch: 28, loss: 0.88, accuracy: 70.59
# train epoch: 29, loss: 0.4894, accuracy: 83.27
#  test epoch: 29, loss: 0.89, accuracy: 70.07
# train epoch: 30, loss: 0.4587, accuracy: 84.37
#  test epoch: 30, loss: 0.87, accuracy: 70.54
# train epoch: 31, loss: 0.4349, accuracy: 85.21
#  test epoch: 31, loss: 0.87, accuracy: 70.50
# train epoch: 32, loss: 0.4221, accuracy: 85.62
#  test epoch: 32, loss: 0.91, accuracy: 70.36
# train epoch: 33, loss: 0.3956, accuracy: 86.55
#  test epoch: 33, loss: 0.88, accuracy: 71.02
# train epoch: 34, loss: 0.3683, accuracy: 87.64
#  test epoch: 34, loss: 0.91, accuracy: 70.60
# train epoch: 35, loss: 0.3474, accuracy: 88.36
#  test epoch: 35, loss: 0.88, accuracy: 70.69
# train epoch: 36, loss: 0.3339, accuracy: 88.87
#  test epoch: 36, loss: 0.92, accuracy: 70.35
# train epoch: 37, loss: 0.3197, accuracy: 89.43
#  test epoch: 37, loss: 0.92, accuracy: 71.31
# train epoch: 38, loss: 0.3082, accuracy: 89.70
#  test epoch: 38, loss: 0.93, accuracy: 70.50
# train epoch: 39, loss: 0.2897, accuracy: 90.39
#  test epoch: 39, loss: 0.89, accuracy: 70.90
# train epoch: 40, loss: 0.2605, accuracy: 91.49
#  test epoch: 40, loss: 0.90, accuracy: 71.56
# train epoch: 41, loss: 0.2545, accuracy: 91.72
#  test epoch: 41, loss: 0.89, accuracy: 71.91
# train epoch: 42, loss: 0.2326, accuracy: 92.44
#  test epoch: 42, loss: 0.92, accuracy: 71.96
# train epoch: 43, loss: 0.2205, accuracy: 92.91
#  test epoch: 43, loss: 0.92, accuracy: 72.20
# train epoch: 44, loss: 0.2094, accuracy: 93.41
#  test epoch: 44, loss: 0.92, accuracy: 72.55
# train epoch: 45, loss: 0.1958, accuracy: 93.80
#  test epoch: 45, loss: 0.91, accuracy: 71.96
# train epoch: 46, loss: 0.2238, accuracy: 92.78
#  test epoch: 46, loss: 0.92, accuracy: 71.78
# train epoch: 47, loss: 0.1894, accuracy: 94.16
#  test epoch: 47, loss: 0.93, accuracy: 71.82
# train epoch: 48, loss: 0.1552, accuracy: 95.21
#  test epoch: 48, loss: 0.98, accuracy: 71.92
# train epoch: 49, loss: 0.1640, accuracy: 94.96
#  test epoch: 49, loss: 0.95, accuracy: 72.14
# train epoch: 50, loss: 0.1658, accuracy: 94.77
#  test epoch: 50, loss: 0.96, accuracy: 71.87
# train epoch: 51, loss: 0.1444, accuracy: 95.62
#  test epoch: 51, loss: 0.97, accuracy: 72.47
# train epoch: 52, loss: 0.1374, accuracy: 95.84
#  test epoch: 52, loss: 0.97, accuracy: 72.03
# train epoch: 53, loss: 0.1281, accuracy: 96.15
#  test epoch: 53, loss: 0.97, accuracy: 72.46
# train epoch: 54, loss: 0.1175, accuracy: 96.49
#  test epoch: 54, loss: 1.00, accuracy: 72.29
# train epoch: 55, loss: 0.1106, accuracy: 96.78
#  test epoch: 55, loss: 1.07, accuracy: 71.70
# train epoch: 56, loss: 0.1143, accuracy: 96.67
#  test epoch: 56, loss: 0.98, accuracy: 72.56
# train epoch: 57, loss: 0.0928, accuracy: 97.42
#  test epoch: 57, loss: 1.05, accuracy: 72.37
# train epoch: 58, loss: 0.0898, accuracy: 97.46
#  test epoch: 58, loss: 1.02, accuracy: 72.76
# train epoch: 59, loss: 0.0775, accuracy: 97.93
#  test epoch: 59, loss: 1.06, accuracy: 73.02
# train epoch: 60, loss: 0.0833, accuracy: 97.74
#  test epoch: 60, loss: 1.03, accuracy: 73.13
# train epoch: 61, loss: 0.0736, accuracy: 97.91
#  test epoch: 61, loss: 1.07, accuracy: 73.05
# train epoch: 62, loss: 0.0679, accuracy: 98.20
#  test epoch: 62, loss: 1.04, accuracy: 72.60
# train epoch: 63, loss: 0.0701, accuracy: 98.00
#  test epoch: 63, loss: 1.07, accuracy: 73.17
# train epoch: 64, loss: 0.0666, accuracy: 98.13
#  test epoch: 64, loss: 1.04, accuracy: 73.08
# train epoch: 65, loss: 0.0639, accuracy: 98.34
#  test epoch: 65, loss: 1.05, accuracy: 73.23
# train epoch: 66, loss: 0.0595, accuracy: 98.41
#  test epoch: 66, loss: 1.07, accuracy: 73.68
# train epoch: 67, loss: 0.0550, accuracy: 98.57
#  test epoch: 67, loss: 1.10, accuracy: 73.85
# train epoch: 68, loss: 0.0496, accuracy: 98.72
#  test epoch: 68, loss: 1.12, accuracy: 73.65
# train epoch: 69, loss: 0.0447, accuracy: 98.92
#  test epoch: 69, loss: 1.09, accuracy: 74.06
# train epoch: 70, loss: 0.0434, accuracy: 98.89
#  test epoch: 70, loss: 1.06, accuracy: 73.67
# train epoch: 71, loss: 0.0637, accuracy: 98.26
#  test epoch: 71, loss: 1.04, accuracy: 73.12
# train epoch: 72, loss: 0.0511, accuracy: 98.70
#  test epoch: 72, loss: 1.09, accuracy: 72.77
# train epoch: 73, loss: 0.0451, accuracy: 98.87
#  test epoch: 73, loss: 1.14, accuracy: 73.10
# train epoch: 74, loss: 0.0410, accuracy: 98.95
#  test epoch: 74, loss: 1.12, accuracy: 73.62
# train epoch: 75, loss: 0.0408, accuracy: 99.00
#  test epoch: 75, loss: 1.15, accuracy: 73.16
# train epoch: 76, loss: 0.0420, accuracy: 98.96
#  test epoch: 76, loss: 1.12, accuracy: 73.22
# train epoch: 77, loss: 0.0396, accuracy: 98.99
#  test epoch: 77, loss: 1.15, accuracy: 73.16
# train epoch: 78, loss: 0.0351, accuracy: 99.18
#  test epoch: 78, loss: 1.15, accuracy: 73.62
# train epoch: 79, loss: 0.0332, accuracy: 99.25
#  test epoch: 79, loss: 1.21, accuracy: 73.09
# train epoch: 80, loss: 0.0288, accuracy: 99.38
#  test epoch: 80, loss: 1.18, accuracy: 73.36
#   0%|          | 0/80 [00:00<?, ?it/s]
# train epoch: 1, loss: 2.2180, accuracy: 15.81
#  test epoch: 1, loss: 2.03, accuracy: 27.73
# train epoch: 2, loss: 1.8500, accuracy: 33.34
#  test epoch: 2, loss: 1.74, accuracy: 38.41
# train epoch: 3, loss: 1.6498, accuracy: 41.33
#  test epoch: 3, loss: 1.61, accuracy: 42.66
# train epoch: 4, loss: 1.5312, accuracy: 45.43
#  test epoch: 4, loss: 1.48, accuracy: 47.37
# train epoch: 5, loss: 1.4373, accuracy: 48.85
#  test epoch: 5, loss: 1.42, accuracy: 49.67
# train epoch: 6, loss: 1.3561, accuracy: 51.86
#  test epoch: 6, loss: 1.38, accuracy: 51.11
# train epoch: 7, loss: 1.2953, accuracy: 53.89
#  test epoch: 7, loss: 1.30, accuracy: 53.17
# train epoch: 8, loss: 1.2401, accuracy: 56.10
#  test epoch: 8, loss: 1.25, accuracy: 55.51
# train epoch: 9, loss: 1.1731, accuracy: 58.47
#  test epoch: 9, loss: 1.20, accuracy: 57.29
# train epoch: 10, loss: 1.1269, accuracy: 60.14
#  test epoch: 10, loss: 1.18, accuracy: 57.79
# train epoch: 11, loss: 1.0825, accuracy: 61.88
#  test epoch: 11, loss: 1.12, accuracy: 59.73
# train epoch: 12, loss: 1.0403, accuracy: 63.24
#  test epoch: 12, loss: 1.18, accuracy: 57.94
# train epoch: 13, loss: 0.9847, accuracy: 65.18
#  test epoch: 13, loss: 1.11, accuracy: 61.08
# train epoch: 14, loss: 0.9391, accuracy: 66.91
#  test epoch: 14, loss: 1.04, accuracy: 63.20
# train epoch: 15, loss: 0.8969, accuracy: 68.50
#  test epoch: 15, loss: 1.04, accuracy: 63.35
# train epoch: 16, loss: 0.8845, accuracy: 69.08
#  test epoch: 16, loss: 1.02, accuracy: 64.17
# train epoch: 17, loss: 0.8296, accuracy: 70.91
#  test epoch: 17, loss: 0.98, accuracy: 65.58
# train epoch: 18, loss: 0.8024, accuracy: 71.96
#  test epoch: 18, loss: 0.97, accuracy: 66.39
# train epoch: 19, loss: 0.7690, accuracy: 73.09
#  test epoch: 19, loss: 0.97, accuracy: 65.97
# train epoch: 20, loss: 0.7440, accuracy: 74.02
#  test epoch: 20, loss: 0.94, accuracy: 67.08
# train epoch: 21, loss: 0.7040, accuracy: 75.49
#  test epoch: 21, loss: 0.94, accuracy: 67.77
# train epoch: 22, loss: 0.6936, accuracy: 75.82
#  test epoch: 22, loss: 0.95, accuracy: 67.07
# train epoch: 23, loss: 0.6698, accuracy: 76.73
#  test epoch: 23, loss: 0.97, accuracy: 66.79
# train epoch: 24, loss: 0.6396, accuracy: 77.73
#  test epoch: 24, loss: 0.91, accuracy: 68.52
# train epoch: 25, loss: 0.6050, accuracy: 78.95
#  test epoch: 25, loss: 0.91, accuracy: 68.21
# train epoch: 26, loss: 0.5816, accuracy: 79.80
#  test epoch: 26, loss: 0.92, accuracy: 69.34
# train epoch: 27, loss: 0.5504, accuracy: 80.85
#  test epoch: 27, loss: 0.92, accuracy: 69.29
# train epoch: 28, loss: 0.5222, accuracy: 81.91
#  test epoch: 28, loss: 0.89, accuracy: 70.10
# train epoch: 29, loss: 0.4846, accuracy: 83.14
#  test epoch: 29, loss: 0.90, accuracy: 69.83
# train epoch: 30, loss: 0.4597, accuracy: 84.26
#  test epoch: 30, loss: 0.89, accuracy: 70.20
# train epoch: 31, loss: 0.4406, accuracy: 85.04
#  test epoch: 31, loss: 0.90, accuracy: 69.78
# train epoch: 32, loss: 0.4194, accuracy: 85.86
#  test epoch: 32, loss: 0.92, accuracy: 70.12
# train epoch: 33, loss: 0.3913, accuracy: 86.62
#  test epoch: 33, loss: 0.91, accuracy: 70.50
# train epoch: 34, loss: 0.3703, accuracy: 87.38
#  test epoch: 34, loss: 0.89, accuracy: 70.56
# train epoch: 35, loss: 0.3540, accuracy: 88.18
#  test epoch: 35, loss: 0.90, accuracy: 70.93
# train epoch: 36, loss: 0.3392, accuracy: 88.61
#  test epoch: 36, loss: 0.91, accuracy: 71.25
# train epoch: 37, loss: 0.3180, accuracy: 89.42
#  test epoch: 37, loss: 0.90, accuracy: 71.34
# train epoch: 38, loss: 0.2915, accuracy: 90.44
#  test epoch: 38, loss: 0.90, accuracy: 71.87
# train epoch: 39, loss: 0.2696, accuracy: 91.09
#  test epoch: 39, loss: 0.91, accuracy: 72.14
# train epoch: 40, loss: 0.2661, accuracy: 91.17
#  test epoch: 40, loss: 0.92, accuracy: 71.82
# train epoch: 41, loss: 0.2418, accuracy: 92.10
#  test epoch: 41, loss: 0.99, accuracy: 70.56
# train epoch: 42, loss: 0.2280, accuracy: 92.65
#  test epoch: 42, loss: 0.94, accuracy: 71.59
# train epoch: 43, loss: 0.2156, accuracy: 93.13
#  test epoch: 43, loss: 0.93, accuracy: 72.02
# train epoch: 44, loss: 0.1968, accuracy: 93.84
#  test epoch: 44, loss: 0.93, accuracy: 72.50
# train epoch: 45, loss: 0.1894, accuracy: 94.10
#  test epoch: 45, loss: 0.93, accuracy: 71.94
# train epoch: 46, loss: 0.1868, accuracy: 94.09
#  test epoch: 46, loss: 1.01, accuracy: 72.06
# train epoch: 47, loss: 0.1703, accuracy: 94.76
#  test epoch: 47, loss: 0.96, accuracy: 72.58
# train epoch: 48, loss: 0.1523, accuracy: 95.37
#  test epoch: 48, loss: 1.00, accuracy: 72.63
# train epoch: 49, loss: 0.1409, accuracy: 95.90
#  test epoch: 49, loss: 0.99, accuracy: 71.91
# train epoch: 50, loss: 0.1341, accuracy: 96.01
#  test epoch: 50, loss: 0.98, accuracy: 72.15
# train epoch: 51, loss: 0.1217, accuracy: 96.47
#  test epoch: 51, loss: 1.02, accuracy: 72.32
# train epoch: 52, loss: 0.1093, accuracy: 96.88
#  test epoch: 52, loss: 1.02, accuracy: 72.31
# train epoch: 53, loss: 0.1098, accuracy: 96.84
#  test epoch: 53, loss: 1.05, accuracy: 72.63
# train epoch: 54, loss: 0.1029, accuracy: 97.07
#  test epoch: 54, loss: 1.04, accuracy: 72.04
# train epoch: 55, loss: 0.1078, accuracy: 96.88
#  test epoch: 55, loss: 1.04, accuracy: 72.01
# train epoch: 56, loss: 0.1070, accuracy: 96.85
#  test epoch: 56, loss: 1.04, accuracy: 72.65
# train epoch: 57, loss: 0.0881, accuracy: 97.52
#  test epoch: 57, loss: 1.04, accuracy: 73.07
# train epoch: 58, loss: 0.0814, accuracy: 97.85
#  test epoch: 58, loss: 1.03, accuracy: 72.58
# train epoch: 59, loss: 0.0760, accuracy: 97.97
#  test epoch: 59, loss: 1.12, accuracy: 72.61
# train epoch: 60, loss: 0.0742, accuracy: 98.04
#  test epoch: 60, loss: 1.06, accuracy: 73.07
# train epoch: 61, loss: 0.0636, accuracy: 98.33
#  test epoch: 61, loss: 1.07, accuracy: 72.67
# train epoch: 62, loss: 0.0632, accuracy: 98.32
#  test epoch: 62, loss: 1.11, accuracy: 73.09
# train epoch: 63, loss: 0.0571, accuracy: 98.54
#  test epoch: 63, loss: 1.10, accuracy: 73.11
# train epoch: 64, loss: 0.0531, accuracy: 98.70
#  test epoch: 64, loss: 1.07, accuracy: 73.54
# train epoch: 65, loss: 0.0516, accuracy: 98.73
#  test epoch: 65, loss: 1.07, accuracy: 73.47
# train epoch: 66, loss: 0.0475, accuracy: 98.85
#  test epoch: 66, loss: 1.13, accuracy: 73.88
# train epoch: 67, loss: 0.0442, accuracy: 98.92
#  test epoch: 67, loss: 1.15, accuracy: 73.91
# train epoch: 68, loss: 0.0431, accuracy: 98.96
#  test epoch: 68, loss: 1.10, accuracy: 73.17
# train epoch: 69, loss: 0.0441, accuracy: 98.93
#  test epoch: 69, loss: 1.12, accuracy: 73.69
# train epoch: 70, loss: 0.0424, accuracy: 98.97
#  test epoch: 70, loss: 1.15, accuracy: 73.47
# train epoch: 71, loss: 0.0407, accuracy: 99.04
#  test epoch: 71, loss: 1.15, accuracy: 73.42
# train epoch: 72, loss: 0.0387, accuracy: 99.06
#  test epoch: 72, loss: 1.16, accuracy: 73.24
# train epoch: 73, loss: 0.0354, accuracy: 99.18
#  test epoch: 73, loss: 1.19, accuracy: 73.19
# train epoch: 74, loss: 0.0330, accuracy: 99.28
#  test epoch: 74, loss: 1.16, accuracy: 73.58
# train epoch: 75, loss: 0.0323, accuracy: 99.22
#  test epoch: 75, loss: 1.14, accuracy: 73.29
# train epoch: 76, loss: 0.0287, accuracy: 99.36
#  test epoch: 76, loss: 1.17, accuracy: 73.84
# train epoch: 77, loss: 0.0277, accuracy: 99.38
#  test epoch: 77, loss: 1.12, accuracy: 73.20
# train epoch: 78, loss: 0.0270, accuracy: 99.38
#  test epoch: 78, loss: 1.18, accuracy: 73.60
# train epoch: 79, loss: 0.0235, accuracy: 99.52
#  test epoch: 79, loss: 1.18, accuracy: 73.80
# train epoch: 80, loss: 0.0241, accuracy: 99.43
#  test epoch: 80, loss: 1.19, accuracy: 73.78
#   0%|          | 0/80 [00:00<?, ?it/s]
# train epoch: 1, loss: 2.1436, accuracy: 19.42
#  test epoch: 1, loss: 1.90, accuracy: 32.00
# train epoch: 2, loss: 1.8147, accuracy: 35.02
#  test epoch: 2, loss: 1.72, accuracy: 38.62
# train epoch: 3, loss: 1.6275, accuracy: 41.88
#  test epoch: 3, loss: 1.56, accuracy: 44.15
# train epoch: 4, loss: 1.5165, accuracy: 45.65
#  test epoch: 4, loss: 1.49, accuracy: 47.49
# train epoch: 5, loss: 1.4278, accuracy: 49.19
#  test epoch: 5, loss: 1.41, accuracy: 49.52
# train epoch: 6, loss: 1.3585, accuracy: 51.40
#  test epoch: 6, loss: 1.37, accuracy: 51.09
# train epoch: 7, loss: 1.2938, accuracy: 53.87
#  test epoch: 7, loss: 1.32, accuracy: 52.98
# train epoch: 8, loss: 1.2349, accuracy: 55.83
#  test epoch: 8, loss: 1.26, accuracy: 55.21
# train epoch: 9, loss: 1.1917, accuracy: 57.42
#  test epoch: 9, loss: 1.19, accuracy: 57.77
# train epoch: 10, loss: 1.1461, accuracy: 59.31
#  test epoch: 10, loss: 1.19, accuracy: 57.45
# train epoch: 11, loss: 1.0952, accuracy: 61.16
#  test epoch: 11, loss: 1.14, accuracy: 59.21
# train epoch: 12, loss: 1.0504, accuracy: 62.75
#  test epoch: 12, loss: 1.11, accuracy: 60.55
# train epoch: 13, loss: 1.0052, accuracy: 64.32
#  test epoch: 13, loss: 1.09, accuracy: 61.14
# train epoch: 14, loss: 0.9678, accuracy: 65.80
#  test epoch: 14, loss: 1.09, accuracy: 61.74
# train epoch: 15, loss: 0.9283, accuracy: 67.34
#  test epoch: 15, loss: 1.06, accuracy: 61.99
# train epoch: 16, loss: 0.8913, accuracy: 68.66
#  test epoch: 16, loss: 1.02, accuracy: 64.47
# train epoch: 17, loss: 0.8533, accuracy: 69.87
#  test epoch: 17, loss: 1.00, accuracy: 64.79
# train epoch: 18, loss: 0.8202, accuracy: 71.51
#  test epoch: 18, loss: 0.98, accuracy: 65.24
# train epoch: 19, loss: 0.7926, accuracy: 72.28
#  test epoch: 19, loss: 0.97, accuracy: 65.83
# train epoch: 20, loss: 0.7577, accuracy: 73.30
#  test epoch: 20, loss: 0.97, accuracy: 65.86
# train epoch: 21, loss: 0.7295, accuracy: 74.39
#  test epoch: 21, loss: 0.95, accuracy: 66.72
# train epoch: 22, loss: 0.7030, accuracy: 75.45
#  test epoch: 22, loss: 0.94, accuracy: 67.42
# train epoch: 23, loss: 0.6781, accuracy: 76.29
#  test epoch: 23, loss: 0.93, accuracy: 67.55
# train epoch: 24, loss: 0.6562, accuracy: 77.21
#  test epoch: 24, loss: 0.93, accuracy: 67.81
# train epoch: 25, loss: 0.6199, accuracy: 78.39
#  test epoch: 25, loss: 0.94, accuracy: 67.61
# train epoch: 26, loss: 0.5914, accuracy: 79.24
#  test epoch: 26, loss: 0.93, accuracy: 68.49
# train epoch: 27, loss: 0.5669, accuracy: 80.16
#  test epoch: 27, loss: 0.90, accuracy: 68.84
# train epoch: 28, loss: 0.5465, accuracy: 81.02
#  test epoch: 28, loss: 0.89, accuracy: 69.67
# train epoch: 29, loss: 0.5100, accuracy: 82.39
#  test epoch: 29, loss: 0.94, accuracy: 68.50
# train epoch: 30, loss: 0.4831, accuracy: 83.41
#  test epoch: 30, loss: 0.90, accuracy: 69.22
# train epoch: 31, loss: 0.4586, accuracy: 84.26
#  test epoch: 31, loss: 0.87, accuracy: 70.44
# train epoch: 32, loss: 0.4306, accuracy: 85.23
#  test epoch: 32, loss: 0.91, accuracy: 70.68
# train epoch: 33, loss: 0.4093, accuracy: 86.28
#  test epoch: 33, loss: 0.89, accuracy: 71.10
# train epoch: 34, loss: 0.3857, accuracy: 86.88
#  test epoch: 34, loss: 0.91, accuracy: 70.72
# train epoch: 35, loss: 0.3566, accuracy: 87.94
#  test epoch: 35, loss: 0.89, accuracy: 70.62
# train epoch: 36, loss: 0.3309, accuracy: 88.93
#  test epoch: 36, loss: 0.88, accuracy: 71.61
# train epoch: 37, loss: 0.3125, accuracy: 89.53
#  test epoch: 37, loss: 0.89, accuracy: 71.81
# train epoch: 38, loss: 0.2886, accuracy: 90.48
#  test epoch: 38, loss: 0.93, accuracy: 71.00
# train epoch: 39, loss: 0.2757, accuracy: 90.87
#  test epoch: 39, loss: 0.94, accuracy: 71.58
# train epoch: 40, loss: 0.2544, accuracy: 91.71
#  test epoch: 40, loss: 0.94, accuracy: 71.01
# train epoch: 41, loss: 0.2404, accuracy: 92.17
#  test epoch: 41, loss: 0.92, accuracy: 71.69
# train epoch: 42, loss: 0.2202, accuracy: 92.95
#  test epoch: 42, loss: 0.92, accuracy: 72.06
# train epoch: 43, loss: 0.2050, accuracy: 93.43
#  test epoch: 43, loss: 0.94, accuracy: 72.20
# train epoch: 44, loss: 0.1982, accuracy: 93.81
#  test epoch: 44, loss: 0.97, accuracy: 71.57
# train epoch: 45, loss: 0.1807, accuracy: 94.22
#  test epoch: 45, loss: 1.00, accuracy: 71.77
# train epoch: 46, loss: 0.1772, accuracy: 94.59
#  test epoch: 46, loss: 0.97, accuracy: 72.63
# train epoch: 47, loss: 0.1582, accuracy: 95.15
#  test epoch: 47, loss: 1.02, accuracy: 72.04
# train epoch: 48, loss: 0.1461, accuracy: 95.59
#  test epoch: 48, loss: 1.01, accuracy: 72.48
# train epoch: 49, loss: 0.1422, accuracy: 95.66
#  test epoch: 49, loss: 1.00, accuracy: 72.61
# train epoch: 50, loss: 0.1358, accuracy: 95.87
#  test epoch: 50, loss: 0.96, accuracy: 72.72
# train epoch: 51, loss: 0.1194, accuracy: 96.47
#  test epoch: 51, loss: 1.00, accuracy: 72.80
# train epoch: 52, loss: 0.1171, accuracy: 96.54
#  test epoch: 52, loss: 0.99, accuracy: 72.73
# train epoch: 53, loss: 0.1083, accuracy: 96.85
#  test epoch: 53, loss: 1.04, accuracy: 72.96
# train epoch: 54, loss: 0.0925, accuracy: 97.47
#  test epoch: 54, loss: 1.05, accuracy: 72.64
# train epoch: 55, loss: 0.0898, accuracy: 97.55
#  test epoch: 55, loss: 1.04, accuracy: 72.56
# train epoch: 56, loss: 0.0878, accuracy: 97.52
#  test epoch: 56, loss: 1.02, accuracy: 73.10
# train epoch: 57, loss: 0.0842, accuracy: 97.61
#  test epoch: 57, loss: 1.01, accuracy: 73.01
# train epoch: 58, loss: 0.0714, accuracy: 98.17
#  test epoch: 58, loss: 1.05, accuracy: 73.59
# train epoch: 59, loss: 0.0699, accuracy: 98.13
#  test epoch: 59, loss: 1.10, accuracy: 72.74
# train epoch: 60, loss: 0.0665, accuracy: 98.28
#  test epoch: 60, loss: 1.08, accuracy: 73.59
# train epoch: 61, loss: 0.0606, accuracy: 98.37
#  test epoch: 61, loss: 1.06, accuracy: 73.45
# train epoch: 62, loss: 0.0584, accuracy: 98.46
#  test epoch: 62, loss: 1.09, accuracy: 73.29
# train epoch: 63, loss: 0.0524, accuracy: 98.69
#  test epoch: 63, loss: 1.09, accuracy: 73.30
# train epoch: 64, loss: 0.0549, accuracy: 98.56
#  test epoch: 64, loss: 1.08, accuracy: 73.75
# train epoch: 65, loss: 0.0455, accuracy: 98.98
#  test epoch: 65, loss: 1.13, accuracy: 72.92
# train epoch: 66, loss: 0.0417, accuracy: 99.02
#  test epoch: 66, loss: 1.16, accuracy: 73.39
# train epoch: 67, loss: 0.0414, accuracy: 99.00
#  test epoch: 67, loss: 1.16, accuracy: 73.24
# train epoch: 68, loss: 0.0411, accuracy: 99.00
#  test epoch: 68, loss: 1.13, accuracy: 73.93
# train epoch: 69, loss: 0.0417, accuracy: 98.93
#  test epoch: 69, loss: 1.17, accuracy: 73.32
# train epoch: 70, loss: 0.0395, accuracy: 99.08
#  test epoch: 70, loss: 1.17, accuracy: 73.73
# train epoch: 71, loss: 0.0356, accuracy: 99.19
#  test epoch: 71, loss: 1.14, accuracy: 73.87
# train epoch: 72, loss: 0.0352, accuracy: 99.15
#  test epoch: 72, loss: 1.13, accuracy: 73.67
# train epoch: 73, loss: 0.0348, accuracy: 99.21
#  test epoch: 73, loss: 1.17, accuracy: 73.87
# train epoch: 74, loss: 0.0312, accuracy: 99.30
#  test epoch: 74, loss: 1.20, accuracy: 73.53
# train epoch: 75, loss: 0.0332, accuracy: 99.23
#  test epoch: 75, loss: 1.17, accuracy: 73.56
# train epoch: 76, loss: 0.0294, accuracy: 99.37
#  test epoch: 76, loss: 1.18, accuracy: 73.38
# train epoch: 77, loss: 0.0307, accuracy: 99.26
#  test epoch: 77, loss: 1.16, accuracy: 73.50
# train epoch: 78, loss: 0.0292, accuracy: 99.35
#  test epoch: 78, loss: 1.15, accuracy: 73.63
# train epoch: 79, loss: 0.0277, accuracy: 99.39
#  test epoch: 79, loss: 1.15, accuracy: 74.05
# train epoch: 80, loss: 0.0238, accuracy: 99.44
#  test epoch: 80, loss: 1.17, accuracy: 73.95
#   0%|          | 0/80 [00:00<?, ?it/s]
# train epoch: 1, loss: 2.1340, accuracy: 21.94
#  test epoch: 1, loss: 1.93, accuracy: 29.86
# train epoch: 2, loss: 1.7417, accuracy: 37.62
#  test epoch: 2, loss: 1.64, accuracy: 42.35
# train epoch: 3, loss: 1.5748, accuracy: 43.72
#  test epoch: 3, loss: 1.50, accuracy: 46.07
# train epoch: 4, loss: 1.4691, accuracy: 47.42
#  test epoch: 4, loss: 1.45, accuracy: 47.67
# train epoch: 5, loss: 1.3762, accuracy: 51.07
#  test epoch: 5, loss: 1.38, accuracy: 51.25
# train epoch: 6, loss: 1.3212, accuracy: 53.15
#  test epoch: 6, loss: 1.31, accuracy: 53.32
# train epoch: 7, loss: 1.2445, accuracy: 55.84
#  test epoch: 7, loss: 1.24, accuracy: 55.34
# train epoch: 8, loss: 1.2087, accuracy: 57.01
#  test epoch: 8, loss: 1.24, accuracy: 55.75
# train epoch: 9, loss: 1.1424, accuracy: 59.39
#  test epoch: 9, loss: 1.18, accuracy: 57.59
# train epoch: 10, loss: 1.1053, accuracy: 60.97
#  test epoch: 10, loss: 1.18, accuracy: 57.43
# train epoch: 11, loss: 1.0537, accuracy: 62.76
#  test epoch: 11, loss: 1.10, accuracy: 60.86
# train epoch: 12, loss: 1.0080, accuracy: 64.31
#  test epoch: 12, loss: 1.08, accuracy: 61.91
# train epoch: 13, loss: 0.9608, accuracy: 66.26
#  test epoch: 13, loss: 1.04, accuracy: 62.75
# train epoch: 14, loss: 0.9343, accuracy: 67.13
#  test epoch: 14, loss: 1.06, accuracy: 62.30
# train epoch: 15, loss: 0.8989, accuracy: 68.45
#  test epoch: 15, loss: 1.02, accuracy: 63.74
# train epoch: 16, loss: 0.8577, accuracy: 70.01
#  test epoch: 16, loss: 0.99, accuracy: 64.99
# train epoch: 17, loss: 0.8293, accuracy: 71.13
#  test epoch: 17, loss: 0.99, accuracy: 65.57
# train epoch: 18, loss: 0.7950, accuracy: 72.30
#  test epoch: 18, loss: 0.95, accuracy: 66.71
# train epoch: 19, loss: 0.7668, accuracy: 73.29
#  test epoch: 19, loss: 0.94, accuracy: 67.00
# train epoch: 20, loss: 0.7291, accuracy: 74.55
#  test epoch: 20, loss: 0.93, accuracy: 67.62
# train epoch: 21, loss: 0.7073, accuracy: 75.51
#  test epoch: 21, loss: 0.92, accuracy: 67.63
# train epoch: 22, loss: 0.6810, accuracy: 76.42
#  test epoch: 22, loss: 0.90, accuracy: 68.35
# train epoch: 23, loss: 0.6468, accuracy: 77.69
#  test epoch: 23, loss: 0.90, accuracy: 68.83
# train epoch: 24, loss: 0.6148, accuracy: 78.68
#  test epoch: 24, loss: 0.87, accuracy: 69.69
# train epoch: 25, loss: 0.5957, accuracy: 79.33
#  test epoch: 25, loss: 0.90, accuracy: 69.25
# train epoch: 26, loss: 0.5710, accuracy: 80.16
#  test epoch: 26, loss: 0.88, accuracy: 70.34
# train epoch: 27, loss: 0.5484, accuracy: 81.23
#  test epoch: 27, loss: 0.92, accuracy: 69.40
# train epoch: 28, loss: 0.5492, accuracy: 80.92
#  test epoch: 28, loss: 0.89, accuracy: 70.08
# train epoch: 29, loss: 0.5135, accuracy: 82.18
#  test epoch: 29, loss: 0.85, accuracy: 71.68
# train epoch: 30, loss: 0.4892, accuracy: 83.14
#  test epoch: 30, loss: 0.86, accuracy: 71.06
# train epoch: 31, loss: 0.4679, accuracy: 83.89
#  test epoch: 31, loss: 0.88, accuracy: 71.21
# train epoch: 32, loss: 0.4438, accuracy: 84.78
#  test epoch: 32, loss: 0.86, accuracy: 71.95
# train epoch: 33, loss: 0.4133, accuracy: 85.79
#  test epoch: 33, loss: 0.88, accuracy: 71.52
# train epoch: 34, loss: 0.4014, accuracy: 86.35
#  test epoch: 34, loss: 0.83, accuracy: 72.42
# train epoch: 35, loss: 0.3756, accuracy: 87.13
#  test epoch: 35, loss: 0.91, accuracy: 71.00
# train epoch: 36, loss: 0.3522, accuracy: 88.13
#  test epoch: 36, loss: 0.85, accuracy: 72.80
# train epoch: 37, loss: 0.3339, accuracy: 88.89
#  test epoch: 37, loss: 0.84, accuracy: 72.52
# train epoch: 38, loss: 0.3112, accuracy: 89.51
#  test epoch: 38, loss: 0.87, accuracy: 72.52
# train epoch: 39, loss: 0.3099, accuracy: 89.58
#  test epoch: 39, loss: 0.86, accuracy: 71.55
# train epoch: 40, loss: 0.2856, accuracy: 90.53
#  test epoch: 40, loss: 0.86, accuracy: 72.62
# train epoch: 41, loss: 0.2656, accuracy: 91.24
#  test epoch: 41, loss: 0.87, accuracy: 72.79
# train epoch: 42, loss: 0.2440, accuracy: 91.99
#  test epoch: 42, loss: 0.86, accuracy: 73.34
# train epoch: 43, loss: 0.2436, accuracy: 91.92
#  test epoch: 43, loss: 0.87, accuracy: 73.06
# train epoch: 44, loss: 0.2243, accuracy: 92.61
#  test epoch: 44, loss: 0.86, accuracy: 73.10
# train epoch: 45, loss: 0.2082, accuracy: 93.28
#  test epoch: 45, loss: 0.92, accuracy: 72.73
# train epoch: 46, loss: 0.1999, accuracy: 93.54
#  test epoch: 46, loss: 0.85, accuracy: 73.11
# train epoch: 47, loss: 0.1924, accuracy: 93.92
#  test epoch: 47, loss: 0.88, accuracy: 73.52
# train epoch: 48, loss: 0.1817, accuracy: 94.24
#  test epoch: 48, loss: 0.89, accuracy: 73.01
# train epoch: 49, loss: 0.1736, accuracy: 94.58
#  test epoch: 49, loss: 0.94, accuracy: 73.15
# train epoch: 50, loss: 0.1577, accuracy: 95.21
#  test epoch: 50, loss: 0.91, accuracy: 73.55
# train epoch: 51, loss: 0.1470, accuracy: 95.44
#  test epoch: 51, loss: 0.91, accuracy: 73.63
# train epoch: 52, loss: 0.1408, accuracy: 95.68
#  test epoch: 52, loss: 0.91, accuracy: 74.13
# train epoch: 53, loss: 0.1368, accuracy: 95.83
#  test epoch: 53, loss: 0.91, accuracy: 74.14
# train epoch: 54, loss: 0.1384, accuracy: 95.67
#  test epoch: 54, loss: 0.94, accuracy: 73.58
# train epoch: 55, loss: 0.1305, accuracy: 96.01
#  test epoch: 55, loss: 0.95, accuracy: 74.19
# train epoch: 56, loss: 0.1146, accuracy: 96.56
#  test epoch: 56, loss: 0.93, accuracy: 74.35
# train epoch: 57, loss: 0.1034, accuracy: 96.95
#  test epoch: 57, loss: 0.96, accuracy: 74.01
# train epoch: 58, loss: 0.0949, accuracy: 97.29
#  test epoch: 58, loss: 0.93, accuracy: 74.43
# train epoch: 59, loss: 0.0907, accuracy: 97.41
#  test epoch: 59, loss: 0.98, accuracy: 73.44
# train epoch: 60, loss: 0.0866, accuracy: 97.54
#  test epoch: 60, loss: 0.97, accuracy: 74.35
# train epoch: 61, loss: 0.0775, accuracy: 97.89
#  test epoch: 61, loss: 0.95, accuracy: 74.64
# train epoch: 62, loss: 0.0720, accuracy: 97.99
#  test epoch: 62, loss: 0.99, accuracy: 74.38
# train epoch: 63, loss: 0.0714, accuracy: 98.07
#  test epoch: 63, loss: 0.98, accuracy: 74.68
# train epoch: 64, loss: 0.0685, accuracy: 98.15
#  test epoch: 64, loss: 0.97, accuracy: 74.87
# train epoch: 65, loss: 0.0668, accuracy: 98.19
#  test epoch: 65, loss: 0.98, accuracy: 74.21
# train epoch: 66, loss: 0.0592, accuracy: 98.46
#  test epoch: 66, loss: 1.01, accuracy: 74.70
# train epoch: 67, loss: 0.0692, accuracy: 98.14
#  test epoch: 67, loss: 0.98, accuracy: 74.34
# train epoch: 68, loss: 0.0652, accuracy: 98.29
#  test epoch: 68, loss: 0.98, accuracy: 74.63
# train epoch: 69, loss: 0.0566, accuracy: 98.59
#  test epoch: 69, loss: 0.99, accuracy: 75.28
# train epoch: 70, loss: 0.0560, accuracy: 98.57
#  test epoch: 70, loss: 1.01, accuracy: 75.36
# train epoch: 71, loss: 0.0566, accuracy: 98.47
#  test epoch: 71, loss: 0.98, accuracy: 75.01
# train epoch: 72, loss: 0.0563, accuracy: 98.55
#  test epoch: 72, loss: 1.02, accuracy: 74.74
# train epoch: 73, loss: 0.0494, accuracy: 98.76
#  test epoch: 73, loss: 1.02, accuracy: 75.00
# train epoch: 74, loss: 0.0509, accuracy: 98.64
#  test epoch: 74, loss: 1.05, accuracy: 74.96
# train epoch: 75, loss: 0.0413, accuracy: 98.95
#  test epoch: 75, loss: 1.04, accuracy: 74.34
# train epoch: 76, loss: 0.0379, accuracy: 99.12
#  test epoch: 76, loss: 1.04, accuracy: 74.98
# train epoch: 77, loss: 0.0356, accuracy: 99.13
#  test epoch: 77, loss: 1.02, accuracy: 75.21
# train epoch: 78, loss: 0.0337, accuracy: 99.21
#  test epoch: 78, loss: 1.06, accuracy: 75.44
# train epoch: 79, loss: 0.0300, accuracy: 99.31
#  test epoch: 79, loss: 1.10, accuracy: 74.68
# train epoch: 80, loss: 0.0283, accuracy: 99.40
#  test epoch: 80, loss: 1.01, accuracy: 75.58

# %%
import pickle
models_params = [m.params for m in models_saved]
with open("cifar_complex_nonrobust.txt", "wb") as fp:   #Pickling
  pickle.dump(models_params, fp)
