# %%
# Requirements
# !pip install tensorflow_datasets flax jax optax tqdm netket imgaug==0.2.6

# %%
import jax
import jax.numpy as jnp
import numpy as np
from matplotlib import pyplot as plt
import tensorflow_datasets as tfds
import jax
import jax.numpy as jnp
import jax
import flax
import netket as nk
import jax.numpy as jnp
from jax.experimental import stax
import optax
from flax.training import train_state  # Useful dataclass to keep train state
from functools import partial
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# ### Utility Functions

# %%
def show_img(img, ax=None, title=None):
  """Shows a single image.
  
  Must be stored as a 3d-tensor where the last dimension is 1 channel (greyscale)
  """
  if ax is None:
    ax = plt.gca()
  ax.imshow(img)
  ax.set_xticks([])
  ax.set_yticks([])
  if title:
    ax.set_title(title)

def show_img_grid(imgs, titles):
  """Shows a grid of images."""
  n = int(np.ceil(len(imgs)**.5))
  _, axs = plt.subplots(n, n, figsize=(3 * n, 3 * n))
  for i, (img, title) in enumerate(zip(imgs, titles)):
    show_img(img, axs[i // n][i % n], title)

# %% [markdown]
# ## Setting up the dataset

# %%
#import
ds_builder = tfds.builder('cifar10')
ds_builder.download_and_prepare()
train_ds = tfds.as_numpy(ds_builder.as_dataset(split='train', batch_size=-1))
test_ds = tfds.as_numpy(ds_builder.as_dataset(split='test', batch_size=-1))

#delete the id 
del train_ds['id']
del test_ds['id']


# Normalize
train_ds['image'] = jnp.float32(train_ds['image']) / 255.
test_ds['image'] = jnp.float32(test_ds['image']) / 255.
print("dataset keys:", train_ds.keys())
print(f"The training dataset has shape: {train_ds['image'].shape} and dtype {train_ds['image'].dtype}")
print(f"The test     dataset has shape: {test_ds['image'].shape} and dtype {train_ds['image'].dtype}")
print("")
print(f"The training labels have shape: {train_ds['label'].shape} and dtype {train_ds['label'].dtype}")
print(f"The test     labels have shape: {test_ds['label'].shape} and dtype {test_ds['label'].dtype}")
print("The mean     of the data stored in the images are: ", np.mean(train_ds['image']))
print("The variance of the data stored in the images are: ", np.var(train_ds['image']))
# Out:
# dataset keys: dict_keys(['image', 'label'])
# The training dataset has shape: (50000, 32, 32, 3) and dtype float32
# The test     dataset has shape: (10000, 32, 32, 3) and dtype float32
#
# The training labels have shape: (50000,) and dtype int64
# The test     labels have shape: (10000,) and dtype int64
# The mean     of the data stored in the images are:  0.45392698
# The variance of the data stored in the images are:  0.059536036

# %% [markdown]
# ##Non-linearities

# %%
def modRelu(z, bias): # relu(|z|+b) * (z / |z|)
    norm = jnp.abs(z)
    scale = nk.nn.relu(norm + bias) / (norm + 1e-6)
    scaled = jax.lax.complex(jnp.real(z)*scale, jnp.imag(z)*scale)
    return scaled
def complex_relu(z):
    return jnp.where(z.real > 0, z, 0)
complex_relu = jax.jit(complex_relu)
modRelu=jax.jit(modRelu)

# %% [markdown]
# ## DropoutComment

# %% [markdown]
#  /!\ You can't use max_pool with complex numbers
#  /!\ To apply dropout you need to add a parameter to init and apply :
#
# logits = model.apply({'params': params}, inputs=inputs, rngs={'dropout': dropout_rng})
# pars = model.init({'params': jax.random.PRNGKey(seed), 'dropout': jax.random.PRNGKey(seed_dropout)}, sample_input)
#
#  But be careful, RNG is hell with jax but before wondering about dropout we need to make this simple model work

# %% [markdown]
# ## Define Model

# %%
class Model(nk.nn.Module):
  n_classes : int = 10
  @nk.nn.compact
  def __call__(self, x, train):
    #make rng for dropout
    dropout_rng = self.make_rng('dropout')

    #first TWO convolutions 3x3 --> 32. Avgpol 2x2 stride 2x2. Dropout 0.2
    x = nk.nn.Conv(features=32, kernel_size=(3, 3))(x)
    x = nk.nn.relu(x)
    x = nk.nn.Conv(features=32, kernel_size=(3, 3))(x)
    x = nk.nn.relu(x)
    x = flax.linen.avg_pool(x, window_shape=(2, 2), strides=(2, 2))
    x = flax.linen.Dropout(0.2, deterministic=not train)(x)

    #second TWO convolutions 64x64 --> 32. Avgpol 2x2 stride 2x2. Dropout 0.2
    x = nk.nn.Conv(features=64, kernel_size=(3, 3))(x)
    x = nk.nn.relu(x)
    x = nk.nn.Conv(features=64, kernel_size=(3, 3))(x)
    x = nk.nn.relu(x)
    x = flax.linen.avg_pool(x, window_shape=(2, 2), strides=(2, 2))
    x = flax.linen.Dropout(0.2, deterministic=not train)(x)

    #third TWO convolutions 128x128 --> 32. Avgpol 2x2 stride 2x2. Dropout 0.2
    x = nk.nn.Conv(features=128, kernel_size=(3, 3))(x)
    x = nk.nn.relu(x)
    x = nk.nn.Conv(features=128, kernel_size=(3, 3))(x)
    x = nk.nn.relu(x)
    x = flax.linen.avg_pool(x, window_shape=(2, 2), strides=(2, 2))
    x = flax.linen.Dropout(0.2, deterministic=not train)(x)


    #flatten and dense 1
    x = x.reshape((x.shape[0], -1)) # Flatten
    x = nk.nn.Dense(features=128)(x)
    x = nk.nn.relu(x)

    #DROPOUT2
    #x = flax.linen.Dropout(0.5, deterministic=not train)(x) 

    #dense2 and softmax
    x = nk.nn.Dense(features=10)(x)
    x = nk.nn.log_softmax(x)
    return x

# %% [markdown]
# ## Loss functions

# %%
# The loss function that we will use
def cross_entropy(*, logits, labels):
    one_hot_labels = jax.nn.one_hot(labels, num_classes=10)
    return -jnp.mean(jnp.sum(one_hot_labels * logits, axis=-1))

# %%
dropout_rng, init_dropout = jax.random.split(jax.random.PRNGKey(1))

# %%
def loss_fn(params, dropout_rng, images, labels):
    """
    Loss function minimised during training of the model.
    """
    logits = model.apply(params, images, rngs={'dropout' : dropout_rng}, train=True)
    return cross_entropy(logits=logits, labels=labels)

def compute_metrics(*, logits, labels):
    """
    Compute metrics of the model during training.
    
    Returns the loss and the accuracy.
    """
    loss = cross_entropy(logits=logits, labels=labels)
    accuracy = jnp.mean(jnp.argmax(logits, -1) == labels)
    metrics = {
      'loss': loss,
      'accuracy': accuracy,
    }
    return metrics

# %% [markdown]
# ## 4 - Create the setup and training loop

# %%
def create_train_state(example, rng, optimiser, dropout_rng):
    """Creates initial `TrainState`, holding the current parameters, state of the
    optimiser and other metadata.
    """
    # Construct the model parameters
    params = model.init({'params' : rng, 'dropout' : dropout_rng}, example, train=True)
        
    # Package all those informations in the model state
    return train_state.TrainState.create(
        apply_fn=model.apply, params=params, tx=optimiser)

# %%
@jax.jit
def eval_metrics(params, batch, dropout_rng):
    """
    This function evaluates the metrics without training the model.
    
    Used to check the performance of the network on training and test datasets.
    """
    logits = model.apply(params, batch['image'], rngs={'dropout' : dropout_rng}, train=False)
    return compute_metrics(logits=logits, labels=batch['label'])

# %%
def fgsm_update(image, data_grad, update_max_norm):
    """
    Compute the FGSM update on an image (or a batch of images)

    @param image: float32 tensor of shape (batch_size, rgb, height, width)
    @param data_grad: float32 tensor of the same shape as `image`. Gradient of the loss with respect to `image`.
    @param update_max_norm: float, the maximum permitted difference between `image` and the output of this function measured in L_inf norm.

    @returns a perturbed version of `image` with the same shape
    """
    # Collect the element-wise sign of the data gradient
    sign_data_grad = jnp.sign(data_grad)
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + update_max_norm*sign_data_grad
    # Adding clipping to maintain [0,1] range
    perturbed_image = jnp.clip(perturbed_image, 0, 1)
    # Return the perturbed image
    return perturbed_image

# %%
def loss_fn2(images, params, dropout_rng, labels):
    """
    Loss function minimised during training of the model.
    """
    logits = model.apply(params, images, rngs={'dropout' : dropout_rng}, train=True)
    return cross_entropy(logits=logits, labels=labels)

# %%
@jax.jit
def train_step(state, batch, dropout_rng):
    """
    Train for a single step.
    
    """
    #Make parameters the only 'free' parameter
    _loss_fn = partial(loss_fn, dropout_rng = dropout_rng, images=batch['image'], labels=batch['label'])
    # construct the function returning the loss value and gradient.
    val_grad_fn = jax.value_and_grad(_loss_fn)
    # compute loss and gradient
    loss, grads = val_grad_fn(state.params)
    grads = jax.tree_map(lambda x: x.conj(), grads) 
    # update the state parameters 
    state = state.apply_gradients(grads=grads)

    metrics = eval_metrics(state.params, batch, dropout_rng)
    
    return state, metrics

# %%
def train_epoch(state, train_ds, batch_size, epoch, rng, dropout_rng, *, max_steps=None):
    """Train for a single `epoch`.
    
    And epoch is composed of several steps, where every step is taken by updating
    the network parameters with a small mini-batch.
    """
    
    # total number of training images
    train_ds_size = len(train_ds['image'])
    
    # Compute how many steps are present in this epoch.
    steps_per_epoch = train_ds_size // batch_size

    # Truncate the number of steps
    if max_steps is not None:
        steps_per_epoch = min(steps_per_epoch, max_steps)

    # generate a random permutation of the indices to shuffle the training
    perms = jax.random.permutation(rng, train_ds_size)
    perms = perms[:steps_per_epoch * batch_size]
    perms = perms.reshape((steps_per_epoch, batch_size))
    
    # execute the training step for every mini-batch
    batch_metrics = []
    for perm in perms:
        batch = {k: v[perm, ...] for k, v in train_ds.items()}
        state, metrics = train_step(state, batch, dropout_rng)
        batch_metrics.append(metrics)

    # compute mean of metrics across each batch in epoch.
    batch_metrics_np = jax.device_get(batch_metrics)
    epoch_metrics_np = {
        k: np.mean([metrics[k] for metrics in batch_metrics_np])
            for k in batch_metrics_np[0]}

    return state, epoch_metrics_np


def evaluate_model(params, test_ds, dropout_rng):
    """
    evaluate the performance of the model on the test dataset
    """
    metrics = eval_metrics(params, test_ds, dropout_rng)
    metrics = jax.device_get(metrics)
    summary = jax.tree_map(lambda x: x.item(), metrics)
    return summary['loss'], summary['accuracy']

# %% [markdown]
# # 5 - Training model

# %%
models_saved = []
for s in range(5):
  # Definition of optimiser HyperParameters
  learning_rate = 0.005
  momentum = 0.9
  optimiser = optax.sgd(learning_rate, momentum)
  num_epochs = 80
  batch_size = 250
  max_steps = 200

  #define rngs
  seed = s #123
  seed_dropout = 10-s #0
  key = {'params': jax.random.PRNGKey(seed), 'dropout': jax.random.PRNGKey(seed_dropout)}

  #init model
  model = Model(n_classes=10)
  sample_input = jnp.ones([1, 32, 32, 3])
  pars = model.init(key, sample_input, train=True)

  # Split the rng to get two keys, one to 'shuffle' the dataset at every iteration,
  # and one to initialise the network
  rng, init_rng = jax.random.split(jax.random.PRNGKey(s))

  state = create_train_state(sample_input, init_rng, optimiser, init_dropout)
  metrics = {"test_loss" : [], "test_accuracy": [], "train_loss":[], "train_accuracy":[]}
  with tqdm(range(1, num_epochs + 1)) as pbar:
      for epoch in pbar:
          # Use a separate PRNG key to permute image data during shuffling
          rng, input_rng = jax.random.split(rng)
          dropout_rng, _ = jax.random.split(dropout_rng)
          # Run an optimization step over a training batch
          state, train_metrics = train_epoch(state, train_ds, batch_size, epoch, input_rng, dropout_rng)
          
          # Evaluate on the test set after each training epoch
          test_loss, test_accuracy = evaluate_model(state.params, test_ds, dropout_rng)
          pbar.write('train epoch: %d, loss: %.4f, accuracy: %.2f' % (epoch, train_metrics['loss'], train_metrics['accuracy'] * 100))
          pbar.write(' test epoch: %d, loss: %.2f, accuracy: %.2f' % (epoch, test_loss, test_accuracy * 100))

          # save data
          metrics["train_loss"].append(train_metrics["loss"])
          metrics["train_accuracy"].append(train_metrics["accuracy"])
          metrics["test_loss"].append(test_loss)
          metrics["test_accuracy"].append(test_accuracy)

  models_saved += [state]
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]
# train epoch: 1, loss: 2.1345, accuracy: 19.30
#  test epoch: 1, loss: 1.92, accuracy: 30.85
# train epoch: 2, loss: 1.8135, accuracy: 34.44
#  test epoch: 2, loss: 1.71, accuracy: 38.87
# train epoch: 3, loss: 1.6614, accuracy: 40.02
#  test epoch: 3, loss: 1.58, accuracy: 43.02
# train epoch: 4, loss: 1.5468, accuracy: 44.01
#  test epoch: 4, loss: 1.52, accuracy: 44.58
# train epoch: 5, loss: 1.4688, accuracy: 46.93
#  test epoch: 5, loss: 1.43, accuracy: 48.02
# train epoch: 6, loss: 1.4060, accuracy: 49.07
#  test epoch: 6, loss: 1.38, accuracy: 50.59
# train epoch: 7, loss: 1.3472, accuracy: 51.39
#  test epoch: 7, loss: 1.35, accuracy: 52.22
# train epoch: 8, loss: 1.2701, accuracy: 54.43
#  test epoch: 8, loss: 1.25, accuracy: 55.05
# train epoch: 9, loss: 1.2035, accuracy: 57.02
#  test epoch: 9, loss: 1.27, accuracy: 55.12
# train epoch: 10, loss: 1.1543, accuracy: 58.95
#  test epoch: 10, loss: 1.15, accuracy: 58.87
# train epoch: 11, loss: 1.1046, accuracy: 60.88
#  test epoch: 11, loss: 1.11, accuracy: 60.13
# train epoch: 12, loss: 1.0653, accuracy: 62.56
#  test epoch: 12, loss: 1.08, accuracy: 61.61
# train epoch: 13, loss: 1.0211, accuracy: 64.07
#  test epoch: 13, loss: 1.05, accuracy: 62.54
# train epoch: 14, loss: 0.9764, accuracy: 65.76
#  test epoch: 14, loss: 1.01, accuracy: 64.20
# train epoch: 15, loss: 0.9407, accuracy: 67.10
#  test epoch: 15, loss: 1.01, accuracy: 65.00
# train epoch: 16, loss: 0.9078, accuracy: 67.97
#  test epoch: 16, loss: 0.98, accuracy: 65.52
# train epoch: 17, loss: 0.8790, accuracy: 69.09
#  test epoch: 17, loss: 0.95, accuracy: 66.47
# train epoch: 18, loss: 0.8498, accuracy: 70.18
#  test epoch: 18, loss: 0.94, accuracy: 66.84
# train epoch: 19, loss: 0.8305, accuracy: 70.93
#  test epoch: 19, loss: 0.93, accuracy: 67.55
# train epoch: 20, loss: 0.7958, accuracy: 72.14
#  test epoch: 20, loss: 0.91, accuracy: 67.88
# train epoch: 21, loss: 0.7768, accuracy: 72.90
#  test epoch: 21, loss: 0.88, accuracy: 69.09
# train epoch: 22, loss: 0.7498, accuracy: 73.79
#  test epoch: 22, loss: 0.90, accuracy: 68.47
# train epoch: 23, loss: 0.7274, accuracy: 74.63
#  test epoch: 23, loss: 0.90, accuracy: 68.57
# train epoch: 24, loss: 0.7091, accuracy: 75.35
#  test epoch: 24, loss: 0.86, accuracy: 70.18
# train epoch: 25, loss: 0.6852, accuracy: 76.21
#  test epoch: 25, loss: 0.85, accuracy: 70.43
# train epoch: 26, loss: 0.6613, accuracy: 76.94
#  test epoch: 26, loss: 0.82, accuracy: 70.97
# train epoch: 27, loss: 0.6388, accuracy: 77.69
#  test epoch: 27, loss: 0.88, accuracy: 70.33
# train epoch: 28, loss: 0.6211, accuracy: 78.57
#  test epoch: 28, loss: 0.82, accuracy: 71.40
# train epoch: 29, loss: 0.6022, accuracy: 79.11
#  test epoch: 29, loss: 0.82, accuracy: 71.11
# train epoch: 30, loss: 0.5794, accuracy: 79.94
#  test epoch: 30, loss: 0.81, accuracy: 71.63
# train epoch: 31, loss: 0.5651, accuracy: 80.45
#  test epoch: 31, loss: 0.82, accuracy: 71.28
# train epoch: 32, loss: 0.5438, accuracy: 81.34
#  test epoch: 32, loss: 0.81, accuracy: 72.21
# train epoch: 33, loss: 0.5255, accuracy: 81.89
#  test epoch: 33, loss: 0.79, accuracy: 72.69
# train epoch: 34, loss: 0.5034, accuracy: 82.75
#  test epoch: 34, loss: 0.80, accuracy: 72.70
# train epoch: 35, loss: 0.4864, accuracy: 83.28
#  test epoch: 35, loss: 0.82, accuracy: 72.01
# train epoch: 36, loss: 0.4713, accuracy: 84.00
#  test epoch: 36, loss: 0.80, accuracy: 73.18
# train epoch: 37, loss: 0.4545, accuracy: 84.52
#  test epoch: 37, loss: 0.82, accuracy: 72.67
# train epoch: 38, loss: 0.4334, accuracy: 85.32
#  test epoch: 38, loss: 0.81, accuracy: 72.72
# train epoch: 39, loss: 0.4155, accuracy: 86.15
#  test epoch: 39, loss: 0.81, accuracy: 73.00
# train epoch: 40, loss: 0.3986, accuracy: 86.53
#  test epoch: 40, loss: 0.79, accuracy: 73.85
# train epoch: 41, loss: 0.3795, accuracy: 87.27
#  test epoch: 41, loss: 0.78, accuracy: 73.51
# train epoch: 42, loss: 0.3638, accuracy: 87.88
#  test epoch: 42, loss: 0.79, accuracy: 74.02
# train epoch: 43, loss: 0.3454, accuracy: 88.53
#  test epoch: 43, loss: 0.81, accuracy: 73.90
# train epoch: 44, loss: 0.3338, accuracy: 88.94
#  test epoch: 44, loss: 0.80, accuracy: 74.04
# train epoch: 45, loss: 0.3174, accuracy: 89.55
#  test epoch: 45, loss: 0.81, accuracy: 73.91
# train epoch: 46, loss: 0.3014, accuracy: 90.18
#  test epoch: 46, loss: 0.80, accuracy: 73.87
# train epoch: 47, loss: 0.2940, accuracy: 90.37
#  test epoch: 47, loss: 0.84, accuracy: 73.52
# train epoch: 48, loss: 0.2742, accuracy: 91.12
#  test epoch: 48, loss: 0.83, accuracy: 74.38
# train epoch: 49, loss: 0.2567, accuracy: 91.80
#  test epoch: 49, loss: 0.83, accuracy: 74.28
# train epoch: 50, loss: 0.2443, accuracy: 92.32
#  test epoch: 50, loss: 0.83, accuracy: 73.94
# train epoch: 51, loss: 0.2383, accuracy: 92.43
#  test epoch: 51, loss: 0.86, accuracy: 73.14
# train epoch: 52, loss: 0.2232, accuracy: 93.01
#  test epoch: 52, loss: 0.84, accuracy: 73.95
# train epoch: 53, loss: 0.2129, accuracy: 93.43
#  test epoch: 53, loss: 0.85, accuracy: 74.63
# train epoch: 54, loss: 0.1984, accuracy: 93.88
#  test epoch: 54, loss: 0.83, accuracy: 74.79
# train epoch: 55, loss: 0.1844, accuracy: 94.48
#  test epoch: 55, loss: 0.91, accuracy: 73.57
# train epoch: 56, loss: 0.1789, accuracy: 94.71
#  test epoch: 56, loss: 0.87, accuracy: 74.21
# train epoch: 57, loss: 0.1655, accuracy: 95.16
#  test epoch: 57, loss: 0.88, accuracy: 73.80
# train epoch: 58, loss: 0.1593, accuracy: 95.41
#  test epoch: 58, loss: 0.89, accuracy: 74.04
# train epoch: 59, loss: 0.1533, accuracy: 95.63
#  test epoch: 59, loss: 0.92, accuracy: 74.26
# train epoch: 60, loss: 0.1368, accuracy: 96.13
#  test epoch: 60, loss: 0.90, accuracy: 74.24
# train epoch: 61, loss: 0.1291, accuracy: 96.40
#  test epoch: 61, loss: 0.93, accuracy: 73.90
# train epoch: 62, loss: 0.1238, accuracy: 96.64
#  test epoch: 62, loss: 0.92, accuracy: 74.24
# train epoch: 63, loss: 0.1136, accuracy: 96.96
#  test epoch: 63, loss: 0.94, accuracy: 74.21
# train epoch: 64, loss: 0.1094, accuracy: 97.17
#  test epoch: 64, loss: 0.95, accuracy: 74.15
# train epoch: 65, loss: 0.1031, accuracy: 97.32
#  test epoch: 65, loss: 0.92, accuracy: 73.96
# train epoch: 66, loss: 0.0970, accuracy: 97.55
#  test epoch: 66, loss: 0.99, accuracy: 73.90
# train epoch: 67, loss: 0.0903, accuracy: 97.72
#  test epoch: 67, loss: 0.96, accuracy: 74.11
# train epoch: 68, loss: 0.0848, accuracy: 97.95
#  test epoch: 68, loss: 1.00, accuracy: 74.40
# train epoch: 69, loss: 0.0789, accuracy: 98.21
#  test epoch: 69, loss: 0.99, accuracy: 74.66
# train epoch: 70, loss: 0.0743, accuracy: 98.24
#  test epoch: 70, loss: 0.96, accuracy: 74.66
# train epoch: 71, loss: 0.0695, accuracy: 98.38
#  test epoch: 71, loss: 1.05, accuracy: 74.12
# train epoch: 72, loss: 0.0656, accuracy: 98.53
#  test epoch: 72, loss: 1.00, accuracy: 74.74
# train epoch: 73, loss: 0.0638, accuracy: 98.58
#  test epoch: 73, loss: 1.04, accuracy: 73.85
# train epoch: 74, loss: 0.0583, accuracy: 98.77
#  test epoch: 74, loss: 1.00, accuracy: 74.52
# train epoch: 75, loss: 0.0586, accuracy: 98.66
#  test epoch: 75, loss: 1.01, accuracy: 73.85
# train epoch: 76, loss: 0.0551, accuracy: 98.81
#  test epoch: 76, loss: 1.02, accuracy: 74.22
# train epoch: 77, loss: 0.0500, accuracy: 98.97
#  test epoch: 77, loss: 1.05, accuracy: 74.30
# train epoch: 78, loss: 0.0454, accuracy: 99.11
#  test epoch: 78, loss: 1.05, accuracy: 74.38
# train epoch: 79, loss: 0.0442, accuracy: 99.13
#  test epoch: 79, loss: 1.05, accuracy: 74.37
# train epoch: 80, loss: 0.0405, accuracy: 99.17
#  test epoch: 80, loss: 1.08, accuracy: 74.65
#   0%|          | 0/80 [00:00<?, ?it/s]
# train epoch: 1, loss: 2.1768, accuracy: 16.81
#  test epoch: 1, loss: 1.95, accuracy: 29.59
# train epoch: 2, loss: 1.8676, accuracy: 32.25
#  test epoch: 2, loss: 1.75, accuracy: 37.84
# train epoch: 3, loss: 1.6914, accuracy: 39.25
#  test epoch: 3, loss: 1.64, accuracy: 41.73
# train epoch: 4, loss: 1.5805, accuracy: 43.42
#  test epoch: 4, loss: 1.55, accuracy: 44.54
# train epoch: 5, loss: 1.4915, accuracy: 46.45
#  test epoch: 5, loss: 1.44, accuracy: 48.05
# train epoch: 6, loss: 1.4300, accuracy: 48.78
#  test epoch: 6, loss: 1.40, accuracy: 49.95
# train epoch: 7, loss: 1.3789, accuracy: 50.39
#  test epoch: 7, loss: 1.40, accuracy: 50.16
# train epoch: 8, loss: 1.3330, accuracy: 52.33
#  test epoch: 8, loss: 1.31, accuracy: 53.27
# train epoch: 9, loss: 1.2835, accuracy: 54.05
#  test epoch: 9, loss: 1.28, accuracy: 54.60
# train epoch: 10, loss: 1.2389, accuracy: 55.63
#  test epoch: 10, loss: 1.23, accuracy: 56.15
# train epoch: 11, loss: 1.1966, accuracy: 57.31
#  test epoch: 11, loss: 1.22, accuracy: 56.67
# train epoch: 12, loss: 1.1545, accuracy: 58.94
#  test epoch: 12, loss: 1.17, accuracy: 58.47
# train epoch: 13, loss: 1.1150, accuracy: 60.47
#  test epoch: 13, loss: 1.15, accuracy: 58.76
# train epoch: 14, loss: 1.0648, accuracy: 62.36
#  test epoch: 14, loss: 1.15, accuracy: 59.71
# train epoch: 15, loss: 1.0277, accuracy: 63.68
#  test epoch: 15, loss: 1.08, accuracy: 61.91
# train epoch: 16, loss: 0.9954, accuracy: 64.79
#  test epoch: 16, loss: 1.07, accuracy: 62.25
# train epoch: 17, loss: 0.9586, accuracy: 66.37
#  test epoch: 17, loss: 1.04, accuracy: 63.04
# train epoch: 18, loss: 0.9228, accuracy: 67.64
#  test epoch: 18, loss: 0.99, accuracy: 65.10
# train epoch: 19, loss: 0.8887, accuracy: 68.82
#  test epoch: 19, loss: 0.98, accuracy: 65.57
# train epoch: 20, loss: 0.8557, accuracy: 70.00
#  test epoch: 20, loss: 0.96, accuracy: 65.90
# train epoch: 21, loss: 0.8325, accuracy: 70.78
#  test epoch: 21, loss: 0.96, accuracy: 66.11
# train epoch: 22, loss: 0.7978, accuracy: 72.25
#  test epoch: 22, loss: 0.92, accuracy: 67.62
# train epoch: 23, loss: 0.7722, accuracy: 73.11
#  test epoch: 23, loss: 0.91, accuracy: 68.38
# train epoch: 24, loss: 0.7411, accuracy: 74.20
#  test epoch: 24, loss: 0.90, accuracy: 68.39
# train epoch: 25, loss: 0.7145, accuracy: 75.20
#  test epoch: 25, loss: 0.87, accuracy: 69.33
# train epoch: 26, loss: 0.6882, accuracy: 76.10
#  test epoch: 26, loss: 0.86, accuracy: 69.92
# train epoch: 27, loss: 0.6667, accuracy: 76.91
#  test epoch: 27, loss: 0.85, accuracy: 70.37
# train epoch: 28, loss: 0.6456, accuracy: 77.80
#  test epoch: 28, loss: 0.83, accuracy: 70.63
# train epoch: 29, loss: 0.6180, accuracy: 78.67
#  test epoch: 29, loss: 0.82, accuracy: 71.51
# train epoch: 30, loss: 0.6002, accuracy: 79.39
#  test epoch: 30, loss: 0.82, accuracy: 71.83
# train epoch: 31, loss: 0.5800, accuracy: 80.02
#  test epoch: 31, loss: 0.80, accuracy: 72.19
# train epoch: 32, loss: 0.5577, accuracy: 80.78
#  test epoch: 32, loss: 0.81, accuracy: 72.37
# train epoch: 33, loss: 0.5376, accuracy: 81.64
#  test epoch: 33, loss: 0.80, accuracy: 72.27
# train epoch: 34, loss: 0.5202, accuracy: 82.17
#  test epoch: 34, loss: 0.80, accuracy: 72.61
# train epoch: 35, loss: 0.4967, accuracy: 82.81
#  test epoch: 35, loss: 0.84, accuracy: 72.03
# train epoch: 36, loss: 0.4826, accuracy: 83.39
#  test epoch: 36, loss: 0.81, accuracy: 72.61
# train epoch: 37, loss: 0.4626, accuracy: 84.33
#  test epoch: 37, loss: 0.78, accuracy: 72.78
# train epoch: 38, loss: 0.4419, accuracy: 85.10
#  test epoch: 38, loss: 0.80, accuracy: 73.13
# train epoch: 39, loss: 0.4227, accuracy: 85.56
#  test epoch: 39, loss: 0.76, accuracy: 73.84
# train epoch: 40, loss: 0.4095, accuracy: 86.01
#  test epoch: 40, loss: 0.79, accuracy: 73.14
# train epoch: 41, loss: 0.3878, accuracy: 86.75
#  test epoch: 41, loss: 0.76, accuracy: 73.81
# train epoch: 42, loss: 0.3704, accuracy: 87.66
#  test epoch: 42, loss: 0.76, accuracy: 74.09
# train epoch: 43, loss: 0.3543, accuracy: 88.06
#  test epoch: 43, loss: 0.77, accuracy: 74.31
# train epoch: 44, loss: 0.3381, accuracy: 88.79
#  test epoch: 44, loss: 0.78, accuracy: 73.85
# train epoch: 45, loss: 0.3203, accuracy: 89.38
#  test epoch: 45, loss: 0.78, accuracy: 73.68
# train epoch: 46, loss: 0.3065, accuracy: 89.89
#  test epoch: 46, loss: 0.80, accuracy: 74.47
# train epoch: 47, loss: 0.2969, accuracy: 90.31
#  test epoch: 47, loss: 0.80, accuracy: 74.27
# train epoch: 48, loss: 0.2790, accuracy: 90.96
#  test epoch: 48, loss: 0.80, accuracy: 74.55
# train epoch: 49, loss: 0.2643, accuracy: 91.54
#  test epoch: 49, loss: 0.82, accuracy: 74.34
# train epoch: 50, loss: 0.2504, accuracy: 91.95
#  test epoch: 50, loss: 0.80, accuracy: 75.01
# train epoch: 51, loss: 0.2357, accuracy: 92.61
#  test epoch: 51, loss: 0.79, accuracy: 74.81
# train epoch: 52, loss: 0.2254, accuracy: 92.93
#  test epoch: 52, loss: 0.81, accuracy: 74.47
# train epoch: 53, loss: 0.2091, accuracy: 93.53
#  test epoch: 53, loss: 0.80, accuracy: 74.82
# train epoch: 54, loss: 0.1995, accuracy: 93.86
#  test epoch: 54, loss: 0.82, accuracy: 75.00
# train epoch: 55, loss: 0.1878, accuracy: 94.26
#  test epoch: 55, loss: 0.83, accuracy: 74.66
# train epoch: 56, loss: 0.1741, accuracy: 94.84
#  test epoch: 56, loss: 0.84, accuracy: 74.71
# train epoch: 57, loss: 0.1668, accuracy: 95.07
#  test epoch: 57, loss: 0.86, accuracy: 75.38
# train epoch: 58, loss: 0.1559, accuracy: 95.39
#  test epoch: 58, loss: 0.86, accuracy: 74.59
# train epoch: 59, loss: 0.1430, accuracy: 96.00
#  test epoch: 59, loss: 0.88, accuracy: 75.01
# train epoch: 60, loss: 0.1419, accuracy: 95.97
#  test epoch: 60, loss: 0.83, accuracy: 75.02
# train epoch: 61, loss: 0.1290, accuracy: 96.46
#  test epoch: 61, loss: 0.87, accuracy: 74.67
# train epoch: 62, loss: 0.1213, accuracy: 96.67
#  test epoch: 62, loss: 0.86, accuracy: 74.91
# train epoch: 63, loss: 0.1132, accuracy: 96.98
#  test epoch: 63, loss: 0.88, accuracy: 75.27
# train epoch: 64, loss: 0.1117, accuracy: 96.96
#  test epoch: 64, loss: 0.92, accuracy: 74.97
# train epoch: 65, loss: 0.1023, accuracy: 97.32
#  test epoch: 65, loss: 0.88, accuracy: 74.83
# train epoch: 66, loss: 0.0957, accuracy: 97.59
#  test epoch: 66, loss: 0.92, accuracy: 75.16
# train epoch: 67, loss: 0.0895, accuracy: 97.82
#  test epoch: 67, loss: 0.93, accuracy: 75.25
# train epoch: 68, loss: 0.0844, accuracy: 97.93
#  test epoch: 68, loss: 0.94, accuracy: 74.53
# train epoch: 69, loss: 0.0806, accuracy: 98.06
#  test epoch: 69, loss: 0.93, accuracy: 74.66
# train epoch: 70, loss: 0.0751, accuracy: 98.23
#  test epoch: 70, loss: 0.99, accuracy: 74.61
# train epoch: 71, loss: 0.0676, accuracy: 98.47
#  test epoch: 71, loss: 0.94, accuracy: 75.08
# train epoch: 72, loss: 0.0672, accuracy: 98.40
#  test epoch: 72, loss: 0.94, accuracy: 75.31
# train epoch: 73, loss: 0.0636, accuracy: 98.66
#  test epoch: 73, loss: 0.95, accuracy: 75.38
# train epoch: 74, loss: 0.0573, accuracy: 98.80
#  test epoch: 74, loss: 0.97, accuracy: 75.22
# train epoch: 75, loss: 0.0551, accuracy: 98.79
#  test epoch: 75, loss: 0.96, accuracy: 75.62
# train epoch: 76, loss: 0.0525, accuracy: 98.92
#  test epoch: 76, loss: 0.98, accuracy: 75.38
# train epoch: 77, loss: 0.0480, accuracy: 99.04
#  test epoch: 77, loss: 1.00, accuracy: 75.31
# train epoch: 78, loss: 0.0454, accuracy: 99.09
#  test epoch: 78, loss: 0.98, accuracy: 75.27
# train epoch: 79, loss: 0.0429, accuracy: 99.23
#  test epoch: 79, loss: 1.01, accuracy: 75.51
# train epoch: 80, loss: 0.0403, accuracy: 99.22
#  test epoch: 80, loss: 1.03, accuracy: 75.40
#   0%|          | 0/80 [00:00<?, ?it/s]
# train epoch: 1, loss: 2.1216, accuracy: 19.87
#  test epoch: 1, loss: 1.90, accuracy: 31.68
# train epoch: 2, loss: 1.8063, accuracy: 35.29
#  test epoch: 2, loss: 1.72, accuracy: 38.61
# train epoch: 3, loss: 1.6508, accuracy: 40.87
#  test epoch: 3, loss: 1.61, accuracy: 41.77
# train epoch: 4, loss: 1.5503, accuracy: 44.11
#  test epoch: 4, loss: 1.52, accuracy: 45.32
# train epoch: 5, loss: 1.4520, accuracy: 47.52
#  test epoch: 5, loss: 1.45, accuracy: 48.21
# train epoch: 6, loss: 1.3922, accuracy: 49.68
#  test epoch: 6, loss: 1.37, accuracy: 50.70
# train epoch: 7, loss: 1.3309, accuracy: 52.21
#  test epoch: 7, loss: 1.31, accuracy: 52.78
# train epoch: 8, loss: 1.2823, accuracy: 54.05
#  test epoch: 8, loss: 1.28, accuracy: 54.27
# train epoch: 9, loss: 1.2275, accuracy: 56.39
#  test epoch: 9, loss: 1.22, accuracy: 56.29
# train epoch: 10, loss: 1.1748, accuracy: 58.23
#  test epoch: 10, loss: 1.20, accuracy: 57.15
# train epoch: 11, loss: 1.1284, accuracy: 59.98
#  test epoch: 11, loss: 1.13, accuracy: 59.37
# train epoch: 12, loss: 1.0843, accuracy: 61.67
#  test epoch: 12, loss: 1.11, accuracy: 60.46
# train epoch: 13, loss: 1.0373, accuracy: 63.39
#  test epoch: 13, loss: 1.12, accuracy: 60.29
# train epoch: 14, loss: 0.9993, accuracy: 64.94
#  test epoch: 14, loss: 1.05, accuracy: 62.20
# train epoch: 15, loss: 0.9619, accuracy: 66.16
#  test epoch: 15, loss: 1.05, accuracy: 62.49
# train epoch: 16, loss: 0.9325, accuracy: 67.23
#  test epoch: 16, loss: 1.01, accuracy: 64.21
# train epoch: 17, loss: 0.8990, accuracy: 68.55
#  test epoch: 17, loss: 0.97, accuracy: 65.65
# train epoch: 18, loss: 0.8668, accuracy: 69.69
#  test epoch: 18, loss: 0.95, accuracy: 65.92
# train epoch: 19, loss: 0.8389, accuracy: 70.76
#  test epoch: 19, loss: 0.94, accuracy: 66.46
# train epoch: 20, loss: 0.8132, accuracy: 71.64
#  test epoch: 20, loss: 1.00, accuracy: 65.37
# train epoch: 21, loss: 0.7949, accuracy: 72.33
#  test epoch: 21, loss: 0.94, accuracy: 66.52
# train epoch: 22, loss: 0.7641, accuracy: 73.48
#  test epoch: 22, loss: 0.91, accuracy: 68.63
# train epoch: 23, loss: 0.7433, accuracy: 74.25
#  test epoch: 23, loss: 0.92, accuracy: 68.09
# train epoch: 24, loss: 0.7144, accuracy: 75.28
#  test epoch: 24, loss: 0.92, accuracy: 67.31
# train epoch: 25, loss: 0.6975, accuracy: 75.84
#  test epoch: 25, loss: 0.87, accuracy: 69.88
# train epoch: 26, loss: 0.6679, accuracy: 76.84
#  test epoch: 26, loss: 0.85, accuracy: 70.55
# train epoch: 27, loss: 0.6521, accuracy: 77.43
#  test epoch: 27, loss: 0.85, accuracy: 70.17
# train epoch: 28, loss: 0.6262, accuracy: 78.29
#  test epoch: 28, loss: 0.84, accuracy: 70.50
# train epoch: 29, loss: 0.6074, accuracy: 78.94
#  test epoch: 29, loss: 0.86, accuracy: 70.46
# train epoch: 30, loss: 0.5831, accuracy: 79.93
#  test epoch: 30, loss: 0.85, accuracy: 70.70
# train epoch: 31, loss: 0.5630, accuracy: 80.44
#  test epoch: 31, loss: 0.84, accuracy: 70.55
# train epoch: 32, loss: 0.5447, accuracy: 81.23
#  test epoch: 32, loss: 0.83, accuracy: 71.72
# train epoch: 33, loss: 0.5259, accuracy: 81.73
#  test epoch: 33, loss: 0.83, accuracy: 71.67
# train epoch: 34, loss: 0.5024, accuracy: 82.79
#  test epoch: 34, loss: 0.83, accuracy: 71.97
# train epoch: 35, loss: 0.4834, accuracy: 83.63
#  test epoch: 35, loss: 0.81, accuracy: 72.46
# train epoch: 36, loss: 0.4700, accuracy: 83.85
#  test epoch: 36, loss: 0.83, accuracy: 71.56
# train epoch: 37, loss: 0.4512, accuracy: 84.59
#  test epoch: 37, loss: 0.81, accuracy: 72.21
# train epoch: 38, loss: 0.4323, accuracy: 85.34
#  test epoch: 38, loss: 0.82, accuracy: 71.89
# train epoch: 39, loss: 0.4143, accuracy: 85.91
#  test epoch: 39, loss: 0.84, accuracy: 72.31
# train epoch: 40, loss: 0.3933, accuracy: 86.87
#  test epoch: 40, loss: 0.83, accuracy: 72.36
# train epoch: 41, loss: 0.3823, accuracy: 87.13
#  test epoch: 41, loss: 0.84, accuracy: 72.43
# train epoch: 42, loss: 0.3607, accuracy: 87.95
#  test epoch: 42, loss: 0.82, accuracy: 73.06
# train epoch: 43, loss: 0.3478, accuracy: 88.39
#  test epoch: 43, loss: 0.82, accuracy: 72.52
# train epoch: 44, loss: 0.3272, accuracy: 89.22
#  test epoch: 44, loss: 0.82, accuracy: 73.09
# train epoch: 45, loss: 0.3116, accuracy: 89.70
#  test epoch: 45, loss: 0.84, accuracy: 72.88
# train epoch: 46, loss: 0.2982, accuracy: 90.18
#  test epoch: 46, loss: 0.85, accuracy: 72.43
# train epoch: 47, loss: 0.2828, accuracy: 90.71
#  test epoch: 47, loss: 0.86, accuracy: 72.81
# train epoch: 48, loss: 0.2670, accuracy: 91.48
#  test epoch: 48, loss: 0.86, accuracy: 72.69
# train epoch: 49, loss: 0.2559, accuracy: 91.82
#  test epoch: 49, loss: 0.87, accuracy: 73.15
# train epoch: 50, loss: 0.2450, accuracy: 92.27
#  test epoch: 50, loss: 0.85, accuracy: 72.83
# train epoch: 51, loss: 0.2266, accuracy: 93.06
#  test epoch: 51, loss: 0.89, accuracy: 73.29
# train epoch: 52, loss: 0.2181, accuracy: 93.23
#  test epoch: 52, loss: 0.87, accuracy: 73.28
# train epoch: 53, loss: 0.2093, accuracy: 93.58
#  test epoch: 53, loss: 0.88, accuracy: 73.46
# train epoch: 54, loss: 0.1929, accuracy: 94.12
#  test epoch: 54, loss: 0.89, accuracy: 73.51
# train epoch: 55, loss: 0.1789, accuracy: 94.63
#  test epoch: 55, loss: 0.88, accuracy: 73.56
# train epoch: 56, loss: 0.1682, accuracy: 95.14
#  test epoch: 56, loss: 0.90, accuracy: 73.54
# train epoch: 57, loss: 0.1609, accuracy: 95.34
#  test epoch: 57, loss: 0.94, accuracy: 73.16
# train epoch: 58, loss: 0.1494, accuracy: 95.77
#  test epoch: 58, loss: 0.92, accuracy: 73.67
# train epoch: 59, loss: 0.1434, accuracy: 95.98
#  test epoch: 59, loss: 0.94, accuracy: 73.03
# train epoch: 60, loss: 0.1332, accuracy: 96.31
#  test epoch: 60, loss: 0.97, accuracy: 73.57
# train epoch: 61, loss: 0.1231, accuracy: 96.71
#  test epoch: 61, loss: 0.95, accuracy: 73.84
# train epoch: 62, loss: 0.1160, accuracy: 96.89
#  test epoch: 62, loss: 0.98, accuracy: 73.50
# train epoch: 63, loss: 0.1153, accuracy: 96.89
#  test epoch: 63, loss: 0.97, accuracy: 73.66
# train epoch: 64, loss: 0.0998, accuracy: 97.34
#  test epoch: 64, loss: 1.00, accuracy: 73.39
# train epoch: 65, loss: 0.0988, accuracy: 97.47
#  test epoch: 65, loss: 0.98, accuracy: 73.51
# train epoch: 66, loss: 0.0906, accuracy: 97.68
#  test epoch: 66, loss: 1.00, accuracy: 73.04
# train epoch: 67, loss: 0.0859, accuracy: 97.97
#  test epoch: 67, loss: 1.04, accuracy: 72.76
# train epoch: 68, loss: 0.0794, accuracy: 98.11
#  test epoch: 68, loss: 1.05, accuracy: 72.78
# train epoch: 69, loss: 0.0753, accuracy: 98.24
#  test epoch: 69, loss: 1.04, accuracy: 73.39
# train epoch: 70, loss: 0.0702, accuracy: 98.37
#  test epoch: 70, loss: 1.08, accuracy: 72.79
# train epoch: 71, loss: 0.0661, accuracy: 98.51
#  test epoch: 71, loss: 1.06, accuracy: 73.27
# train epoch: 72, loss: 0.0617, accuracy: 98.64
#  test epoch: 72, loss: 1.04, accuracy: 73.52
# train epoch: 73, loss: 0.0577, accuracy: 98.72
#  test epoch: 73, loss: 1.06, accuracy: 73.56
# train epoch: 74, loss: 0.0537, accuracy: 98.82
#  test epoch: 74, loss: 1.11, accuracy: 73.29
# train epoch: 75, loss: 0.0538, accuracy: 98.86
#  test epoch: 75, loss: 1.10, accuracy: 73.32
# train epoch: 76, loss: 0.0512, accuracy: 98.97
#  test epoch: 76, loss: 1.09, accuracy: 73.64
# train epoch: 77, loss: 0.0455, accuracy: 99.07
#  test epoch: 77, loss: 1.08, accuracy: 73.49
# train epoch: 78, loss: 0.0440, accuracy: 99.12
#  test epoch: 78, loss: 1.11, accuracy: 72.99
# train epoch: 79, loss: 0.0432, accuracy: 99.15
#  test epoch: 79, loss: 1.10, accuracy: 73.89
# train epoch: 80, loss: 0.0387, accuracy: 99.26
#  test epoch: 80, loss: 1.09, accuracy: 73.49
#   0%|          | 0/80 [00:00<?, ?it/s]
# train epoch: 1, loss: 2.1026, accuracy: 21.54
#  test epoch: 1, loss: 1.89, accuracy: 33.22
# train epoch: 2, loss: 1.8210, accuracy: 34.88
#  test epoch: 2, loss: 1.74, accuracy: 38.11
# train epoch: 3, loss: 1.6533, accuracy: 40.76
#  test epoch: 3, loss: 1.60, accuracy: 42.68
# train epoch: 4, loss: 1.5263, accuracy: 45.13
#  test epoch: 4, loss: 1.47, accuracy: 47.26
# train epoch: 5, loss: 1.4552, accuracy: 47.70
#  test epoch: 5, loss: 1.43, accuracy: 49.43
# train epoch: 6, loss: 1.3941, accuracy: 49.96
#  test epoch: 6, loss: 1.39, accuracy: 50.68
# train epoch: 7, loss: 1.3289, accuracy: 52.20
#  test epoch: 7, loss: 1.33, accuracy: 52.15
# train epoch: 8, loss: 1.2882, accuracy: 53.79
#  test epoch: 8, loss: 1.28, accuracy: 54.27
# train epoch: 9, loss: 1.2343, accuracy: 55.90
#  test epoch: 9, loss: 1.25, accuracy: 55.89
# train epoch: 10, loss: 1.1940, accuracy: 57.40
#  test epoch: 10, loss: 1.21, accuracy: 56.77
# train epoch: 11, loss: 1.1503, accuracy: 59.03
#  test epoch: 11, loss: 1.20, accuracy: 56.98
# train epoch: 12, loss: 1.1112, accuracy: 60.56
#  test epoch: 12, loss: 1.14, accuracy: 58.63
# train epoch: 13, loss: 1.0658, accuracy: 62.25
#  test epoch: 13, loss: 1.14, accuracy: 59.36
# train epoch: 14, loss: 1.0281, accuracy: 63.65
#  test epoch: 14, loss: 1.10, accuracy: 61.18
# train epoch: 15, loss: 0.9952, accuracy: 64.92
#  test epoch: 15, loss: 1.05, accuracy: 62.38
# train epoch: 16, loss: 0.9637, accuracy: 66.13
#  test epoch: 16, loss: 1.05, accuracy: 62.86
# train epoch: 17, loss: 0.9368, accuracy: 67.19
#  test epoch: 17, loss: 1.01, accuracy: 63.77
# train epoch: 18, loss: 0.9075, accuracy: 68.17
#  test epoch: 18, loss: 1.01, accuracy: 64.44
# train epoch: 19, loss: 0.8786, accuracy: 69.13
#  test epoch: 19, loss: 1.04, accuracy: 63.66
# train epoch: 20, loss: 0.8437, accuracy: 70.55
#  test epoch: 20, loss: 1.00, accuracy: 64.89
# train epoch: 21, loss: 0.8198, accuracy: 71.27
#  test epoch: 21, loss: 0.98, accuracy: 65.48
# train epoch: 22, loss: 0.7961, accuracy: 72.26
#  test epoch: 22, loss: 1.01, accuracy: 64.56
# train epoch: 23, loss: 0.7703, accuracy: 73.26
#  test epoch: 23, loss: 0.94, accuracy: 67.46
# train epoch: 24, loss: 0.7495, accuracy: 73.93
#  test epoch: 24, loss: 0.92, accuracy: 67.51
# train epoch: 25, loss: 0.7167, accuracy: 75.06
#  test epoch: 25, loss: 0.90, accuracy: 68.30
# train epoch: 26, loss: 0.6928, accuracy: 75.84
#  test epoch: 26, loss: 0.91, accuracy: 68.53
# train epoch: 27, loss: 0.6711, accuracy: 76.68
#  test epoch: 27, loss: 0.90, accuracy: 68.42
# train epoch: 28, loss: 0.6485, accuracy: 77.38
#  test epoch: 28, loss: 0.88, accuracy: 69.71
# train epoch: 29, loss: 0.6222, accuracy: 78.30
#  test epoch: 29, loss: 0.87, accuracy: 69.78
# train epoch: 30, loss: 0.6083, accuracy: 78.88
#  test epoch: 30, loss: 0.88, accuracy: 69.49
# train epoch: 31, loss: 0.5834, accuracy: 79.84
#  test epoch: 31, loss: 0.88, accuracy: 69.96
# train epoch: 32, loss: 0.5628, accuracy: 80.68
#  test epoch: 32, loss: 0.86, accuracy: 70.55
# train epoch: 33, loss: 0.5367, accuracy: 81.49
#  test epoch: 33, loss: 0.86, accuracy: 70.72
# train epoch: 34, loss: 0.5223, accuracy: 81.99
#  test epoch: 34, loss: 0.86, accuracy: 71.06
# train epoch: 35, loss: 0.5009, accuracy: 82.70
#  test epoch: 35, loss: 0.86, accuracy: 71.14
# train epoch: 36, loss: 0.4774, accuracy: 83.75
#  test epoch: 36, loss: 0.88, accuracy: 71.02
# train epoch: 37, loss: 0.4594, accuracy: 84.32
#  test epoch: 37, loss: 0.85, accuracy: 71.69
# train epoch: 38, loss: 0.4412, accuracy: 84.96
#  test epoch: 38, loss: 0.85, accuracy: 70.85
# train epoch: 39, loss: 0.4192, accuracy: 85.92
#  test epoch: 39, loss: 0.82, accuracy: 72.21
# train epoch: 40, loss: 0.4005, accuracy: 86.52
#  test epoch: 40, loss: 0.85, accuracy: 71.82
# train epoch: 41, loss: 0.3849, accuracy: 87.04
#  test epoch: 41, loss: 0.87, accuracy: 72.37
# train epoch: 42, loss: 0.3694, accuracy: 87.75
#  test epoch: 42, loss: 0.85, accuracy: 72.19
# train epoch: 43, loss: 0.3497, accuracy: 88.33
#  test epoch: 43, loss: 0.86, accuracy: 72.62
# train epoch: 44, loss: 0.3372, accuracy: 88.91
#  test epoch: 44, loss: 0.87, accuracy: 72.17
# train epoch: 45, loss: 0.3157, accuracy: 89.54
#  test epoch: 45, loss: 0.86, accuracy: 73.07
# train epoch: 46, loss: 0.3039, accuracy: 90.19
#  test epoch: 46, loss: 0.85, accuracy: 72.74
# train epoch: 47, loss: 0.2857, accuracy: 90.82
#  test epoch: 47, loss: 0.87, accuracy: 72.82
# train epoch: 48, loss: 0.2677, accuracy: 91.47
#  test epoch: 48, loss: 0.87, accuracy: 72.88
# train epoch: 49, loss: 0.2604, accuracy: 91.81
#  test epoch: 49, loss: 0.87, accuracy: 72.95
# train epoch: 50, loss: 0.2436, accuracy: 92.34
#  test epoch: 50, loss: 0.88, accuracy: 72.94
# train epoch: 51, loss: 0.2283, accuracy: 92.92
#  test epoch: 51, loss: 0.90, accuracy: 73.09
# train epoch: 52, loss: 0.2171, accuracy: 93.31
#  test epoch: 52, loss: 0.90, accuracy: 73.21
# train epoch: 53, loss: 0.2040, accuracy: 93.81
#  test epoch: 53, loss: 0.91, accuracy: 73.10
# train epoch: 54, loss: 0.1960, accuracy: 94.08
#  test epoch: 54, loss: 0.96, accuracy: 72.55
# train epoch: 55, loss: 0.1841, accuracy: 94.41
#  test epoch: 55, loss: 0.94, accuracy: 72.51
# train epoch: 56, loss: 0.1700, accuracy: 94.91
#  test epoch: 56, loss: 0.93, accuracy: 73.39
# train epoch: 57, loss: 0.1624, accuracy: 95.15
#  test epoch: 57, loss: 0.95, accuracy: 72.24
# train epoch: 58, loss: 0.1550, accuracy: 95.58
#  test epoch: 58, loss: 0.94, accuracy: 73.08
# train epoch: 59, loss: 0.1429, accuracy: 95.99
#  test epoch: 59, loss: 0.97, accuracy: 73.23
# train epoch: 60, loss: 0.1347, accuracy: 96.32
#  test epoch: 60, loss: 0.95, accuracy: 73.49
# train epoch: 61, loss: 0.1295, accuracy: 96.50
#  test epoch: 61, loss: 0.98, accuracy: 73.46
# train epoch: 62, loss: 0.1230, accuracy: 96.67
#  test epoch: 62, loss: 1.01, accuracy: 73.52
# train epoch: 63, loss: 0.1148, accuracy: 97.02
#  test epoch: 63, loss: 0.97, accuracy: 73.55
# train epoch: 64, loss: 0.1069, accuracy: 97.23
#  test epoch: 64, loss: 0.99, accuracy: 73.34
# train epoch: 65, loss: 0.1009, accuracy: 97.43
#  test epoch: 65, loss: 1.02, accuracy: 72.73
# train epoch: 66, loss: 0.0990, accuracy: 97.41
#  test epoch: 66, loss: 1.02, accuracy: 73.54
# train epoch: 67, loss: 0.0874, accuracy: 97.81
#  test epoch: 67, loss: 1.01, accuracy: 72.98
# train epoch: 68, loss: 0.0836, accuracy: 97.92
#  test epoch: 68, loss: 0.99, accuracy: 73.05
# train epoch: 69, loss: 0.0768, accuracy: 98.14
#  test epoch: 69, loss: 1.06, accuracy: 73.03
# train epoch: 70, loss: 0.0744, accuracy: 98.20
#  test epoch: 70, loss: 1.06, accuracy: 73.52
# train epoch: 71, loss: 0.0704, accuracy: 98.40
#  test epoch: 71, loss: 1.07, accuracy: 73.38
# train epoch: 72, loss: 0.0656, accuracy: 98.52
#  test epoch: 72, loss: 1.05, accuracy: 73.25
# train epoch: 73, loss: 0.0616, accuracy: 98.63
#  test epoch: 73, loss: 1.05, accuracy: 73.90
# train epoch: 74, loss: 0.0575, accuracy: 98.75
#  test epoch: 74, loss: 1.05, accuracy: 73.01
# train epoch: 75, loss: 0.0552, accuracy: 98.83
#  test epoch: 75, loss: 1.07, accuracy: 73.39
# train epoch: 76, loss: 0.0513, accuracy: 98.93
#  test epoch: 76, loss: 1.09, accuracy: 74.15
# train epoch: 77, loss: 0.0486, accuracy: 99.07
#  test epoch: 77, loss: 1.08, accuracy: 73.70
# train epoch: 78, loss: 0.0484, accuracy: 98.98
#  test epoch: 78, loss: 1.13, accuracy: 73.58
# train epoch: 79, loss: 0.0427, accuracy: 99.17
#  test epoch: 79, loss: 1.12, accuracy: 74.16
# train epoch: 80, loss: 0.0427, accuracy: 99.15
#  test epoch: 80, loss: 1.12, accuracy: 73.50

# %%
import pickle
models_params = [m.params for m in models_saved]
with open("cifar_real_nonrobust.txt", "wb") as fp:   #Pickling
  pickle.dump(models_params, fp)

# %%
#computing the number of parameters
tot_params = 0
for chiave in models_saved[0].params['params'].keys():
  for sotto_chiave in models_saved[0].params['params'][chiave]:
    print(chiave, ' \t', 
          sotto_chiave, '  \t', 
          models_saved[0].params['params'][chiave][sotto_chiave].size, '    \t', 
          models_saved[0].params['params'][chiave][sotto_chiave].dtype)
    tot_params += models_saved[0].params['params'][chiave][sotto_chiave].size
print('tot: ', tot_params)
# Out:
# Conv_0  	 bias   	 32     	 float64
# Conv_0  	 kernel   	 864     	 float64
# Conv_1  	 bias   	 32     	 float64
# Conv_1  	 kernel   	 9216     	 float64
# Conv_2  	 bias   	 64     	 float64
# Conv_2  	 kernel   	 18432     	 float64
# Conv_3  	 bias   	 64     	 float64
# Conv_3  	 kernel   	 36864     	 float64
# Conv_4  	 bias   	 128     	 float64
# Conv_4  	 kernel   	 73728     	 float64
# Conv_5  	 bias   	 128     	 float64
# Conv_5  	 kernel   	 147456     	 float64
# Dense_0  	 bias   	 128     	 float64
# Dense_0  	 kernel   	 262144     	 float64
# Dense_1  	 bias   	 10     	 float64
# Dense_1  	 kernel   	 1280     	 float64
# tot:  550570
